# %% [markdown]
# # Open the data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6) # inches
plt.rcParams['font.size'] = 9

# %%
columns = ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E', 'Njets']
for i in range (1,16):
    columns.append( 'jet' + str(i) + '_pt' )
    columns.append( 'jet' + str(i) + '_eta' )
    columns.append( 'jet' + str(i) + '_phi' )
    columns.append( 'jet' + str(i) + '_E' )
    columns.append( 'jet' + str(i) + '_DL1R' )
    
print (columns)
# Out:
# ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E', 'Njets', 'jet1_pt', 'jet1_eta', 'jet1_phi', 'jet1_E', 'jet1_DL1R', 'jet2_pt', 'jet2_eta', 'jet2_phi', 'jet2_E', 'jet2_DL1R', 'jet3_pt', 'jet3_eta', 'jet3_phi', 'jet3_E', 'jet3_DL1R', 'jet4_pt', 'jet4_eta', 'jet4_phi', 'jet4_E', 'jet4_DL1R', 'jet5_pt', 'jet5_eta', 'jet5_phi', 'jet5_E', 'jet5_DL1R', 'jet6_pt', 'jet6_eta', 'jet6_phi', 'jet6_E', 'jet6_DL1R', 'jet7_pt', 'jet7_eta', 'jet7_phi', 'jet7_E', 'jet7_DL1R', 'jet8_pt', 'jet8_eta', 'jet8_phi', 'jet8_E', 'jet8_DL1R', 'jet9_pt', 'jet9_eta', 'jet9_phi', 'jet9_E', 'jet9_DL1R', 'jet10_pt', 'jet10_eta', 'jet10_phi', 'jet10_E', 'jet10_DL1R', 'jet11_pt', 'jet11_eta', 'jet11_phi', 'jet11_E', 'jet11_DL1R', 'jet12_pt', 'jet12_eta', 'jet12_phi', 'jet12_E', 'jet12_DL1R', 'jet13_pt', 'jet13_eta', 'jet13_phi', 'jet13_E', 'jet13_DL1R', 'jet14_pt', 'jet14_eta', 'jet14_phi', 'jet14_E', 'jet14_DL1R', 'jet15_pt', 'jet15_eta', 'jet15_phi', 'jet15_E', 'jet15_DL1R']

# %%
dataf = pd.read_csv('tH_gamgambWqq.csv', header = None, names = columns)

# %%
dataf.head()
# Out:
#       y1_pt    y1_eta    y1_phi      y1_E     y2_pt    y2_eta    y2_phi  \
# 0  390375.0 -0.547024  0.022353  450253.0   88331.8 -1.196040 -0.110091
# 1   88909.4 -1.707230  1.613110  253171.0   36525.8 -0.128228  2.990240
# 2  236877.0  1.705330 -0.967860  673312.0   42001.2  0.576428 -1.403090
# 3  168441.0 -1.783590  1.083770  515366.0   46945.1 -1.366870  2.594060
# 4  384296.0  0.165686  0.932733  389583.0  281261.0 -0.092400  0.652804
#
#        y2_E  Njets   jet1_pt  ...  jet14_pt  jet14_eta  jet14_phi  jet14_E  \
# 0  159411.0      4  244599.0  ...       NaN        NaN        NaN      NaN
# 1   36826.5      4  113569.0  ...       NaN        NaN        NaN      NaN
# 2   49174.4      5  123003.0  ...       NaN        NaN        NaN      NaN
# 3   98066.9      3   88992.7  ...       NaN        NaN        NaN      NaN
# 4  282462.0      5  337068.0  ...       NaN        NaN        NaN      NaN
#
#    jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  jet15_E  jet15_DL1R
# 0         NaN       NaN        NaN        NaN      NaN         NaN
# 1         NaN       NaN        NaN        NaN      NaN         NaN
# 2         NaN       NaN        NaN        NaN      NaN         NaN
# 3         NaN       NaN        NaN        NaN      NaN         NaN
# 4         NaN       NaN        NaN        NaN      NaN         NaN
#
# [5 rows x 84 columns]

# %%
dataf.shape
# Out:
# (111310, 84)

# %% [markdown]
# # Look at the jets

# %%
dataf.describe()['Njets'][['min', 'max']]
# Out:
# min     3.0
# max    15.0
# Name: Njets, dtype: float64

# %%
n, bins, patches = plt.hist(dataf['Njets'], bins = 12, color = 'blue');

# %% [markdown]
# # Make cut of only photon information

# %%
photons = dataf.drop(dataf.columns[np.arange(9, 84)], axis=1)
photons
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E     y2_pt    y2_eta    y2_phi  \
# 0       390375.0 -0.547024  0.022353  450253.0   88331.8 -1.196040 -0.110091
# 1        88909.4 -1.707230  1.613110  253171.0   36525.8 -0.128228  2.990240
# 2       236877.0  1.705330 -0.967860  673312.0   42001.2  0.576428 -1.403090
# 3       168441.0 -1.783590  1.083770  515366.0   46945.1 -1.366870  2.594060
# 4       384296.0  0.165686  0.932733  389583.0  281261.0 -0.092400  0.652804
# ...          ...       ...       ...       ...       ...       ...       ...
# 111305  126436.0 -0.646720 -1.864920  153811.0   31523.1 -0.998545  1.815580
# 111306  101824.0  0.235308  0.018492  104656.0   50372.3 -0.009167 -2.157660
# 111307   72512.1  0.265093 -2.506930   75074.9   68986.0  1.779620 -1.822220
# 111308  125397.0  1.746290  1.189130  370404.0   58541.7  1.572810 -0.466225
# 111309  205179.0 -1.342500  2.760900  419568.0   76309.0 -0.450990 -3.103890
#
#             y2_E  Njets
# 0       159411.0      4
# 1        36826.5      4
# 2        49174.4      5
# 3        98066.9      3
# 4       282462.0      5
# ...          ...    ...
# 111305   48588.8      3
# 111306   50374.4      4
# 111307  210279.0      3
# 111308  147164.0      3
# 111309   84201.8      5
#
# [111310 rows x 9 columns]

# %% [markdown]
# # Cut data to only include jet information

# %%
data = dataf.drop(dataf.columns[np.arange(0, 9)], axis=1)

# %%
data
# Out:
#          jet1_pt  jet1_eta  jet1_phi     jet1_E  jet1_DL1R   jet2_pt  \
# 0       244599.0 -2.590770 -3.063440  1640840.0  -1.031460  174304.0
# 1       113569.0 -0.526400 -1.441500   129917.0   4.693190   54133.2
# 2       123003.0 -0.615800  2.021560   147629.0  -1.612100  122165.0
# 3        88992.7  0.670236 -1.658600   110748.0   8.914730   36598.6
# 4       337068.0 -0.855149 -1.318100   469178.0   8.574970  295253.0
# ...          ...       ...       ...        ...        ...       ...
# 111305   47528.4  0.539272  1.867090    55095.0  -0.638871   40677.3
# 111306   83327.8 -1.129970  2.671090   143007.0  -2.038660   59241.5
# 111307  109837.0  1.735830  0.043495   321476.0   2.028460   68698.4
# 111308   89642.8  0.098086 -2.147140    90266.9  -3.004310   31426.0
# 111309  119254.0  0.106681 -0.631169   121036.0  -4.518370  109844.0
#
#         jet2_eta  jet2_phi    jet2_E  jet2_DL1R  ...  jet14_pt  jet14_eta  \
# 0      -2.286610  2.870830  866922.0  -2.670180  ...       NaN        NaN
# 1       0.426996  1.809370   59619.7  -3.269760  ...       NaN        NaN
# 2      -0.013600  2.083820  122319.0  -5.907740  ...       NaN        NaN
# 3       1.108590 -1.685520   61847.2   0.756823  ...       NaN        NaN
# 4       1.501440 -2.842200  697234.0  -2.729690  ...       NaN        NaN
# ...          ...       ...       ...        ...  ...       ...        ...
# 111305  1.507070  0.121815   96737.3  -1.984430  ...       NaN        NaN
# 111306 -1.462060 -2.934310  135388.0  -2.926370  ...       NaN        NaN
# 111307  0.916289  0.285153   99945.5  -2.374830  ...       NaN        NaN
# 111308 -2.468970 -2.327310  186996.0  -0.818002  ...       NaN        NaN
# 111309 -0.448321 -0.226540  121284.0  -2.441600  ...       NaN        NaN
#
#         jet14_phi  jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  \
# 0             NaN      NaN         NaN       NaN        NaN        NaN
# 1             NaN      NaN         NaN       NaN        NaN        NaN
# 2             NaN      NaN         NaN       NaN        NaN        NaN
# 3             NaN      NaN         NaN       NaN        NaN        NaN
# 4             NaN      NaN         NaN       NaN        NaN        NaN
# ...           ...      ...         ...       ...        ...        ...
# 111305        NaN      NaN         NaN       NaN        NaN        NaN
# 111306        NaN      NaN         NaN       NaN        NaN        NaN
# 111307        NaN      NaN         NaN       NaN        NaN        NaN
# 111308        NaN      NaN         NaN       NaN        NaN        NaN
# 111309        NaN      NaN         NaN       NaN        NaN        NaN
#
#         jet15_E  jet15_DL1R
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 111305      NaN         NaN
# 111306      NaN         NaN
# 111307      NaN         NaN
# 111308      NaN         NaN
# 111309      NaN         NaN
#
# [111310 rows x 75 columns]

# %% [markdown]
# # Begin resorting data by DL1R values

# %%
d_array = data.values

# %%
d_array.shape
# Out:
# (111310, 75)

# %%
d_array_f = np.nan_to_num(d_array, nan = -9000)

# %%
data_array_r = d_array_f.reshape(111310, 15, 5)

# %%
data_array_r.shape
# Out:
# (111310, 15, 5)

# %%
for i in range(111310):
    data_array_r[i] = data_array_r[i, :, :][data_array_r[i, :, 4].argsort()[::-1]]

# %%
print (data_array_r)
# Out:
# [[[ 1.11925e+05 -1.86603e+00  3.08562e+00  3.70719e+05  9.60109e+00]
#   [ 2.44599e+05 -2.59077e+00 -3.06344e+00  1.64084e+06 -1.03146e+00]
#   [ 1.74304e+05 -2.28661e+00  2.87083e+00  8.66922e+05 -2.67018e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]
#
#  [[ 1.13569e+05 -5.26400e-01 -1.44150e+00  1.29917e+05  4.69319e+00]
#   [ 3.90713e+04 -1.77181e+00 -1.08286e+00  1.18313e+05  2.82053e-01]
#   [ 3.69683e+04  2.06752e+00  1.78309e+00  1.48562e+05 -3.05691e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]
#
#  [[ 4.35414e+04  7.11012e-01  1.89783e+00  5.54259e+04  5.73762e+00]
#   [ 1.23003e+05 -6.15800e-01  2.02156e+00  1.47629e+05 -1.61210e+00]
#   [ 8.10699e+04 -1.49316e+00 -2.62835e+00  1.90034e+05 -1.89234e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]
#
#  ...
#
#  [[ 1.09837e+05  1.73583e+00  4.34948e-02  3.21476e+05  2.02846e+00]
#   [ 5.08531e+04  7.72852e-01  2.42547e+00  6.74136e+04 -1.66398e+00]
#   [ 6.86984e+04  9.16289e-01  2.85153e-01  9.99455e+04 -2.37483e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]
#
#  [[ 2.96162e+04  1.58694e+00  2.78388e+00  7.56293e+04  8.75285e+00]
#   [ 3.14260e+04 -2.46897e+00 -2.32731e+00  1.86996e+05 -8.18002e-01]
#   [ 8.96428e+04  9.80855e-02 -2.14714e+00  9.02669e+04 -3.00431e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]
#
#  [[ 8.53376e+04  3.08503e-01  5.58505e-01  9.00912e+04  8.09793e+00]
#   [ 4.90272e+04  2.64445e+00  2.15428e+00  3.46837e+05 -2.21186e+00]
#   [ 1.09844e+05 -4.48321e-01 -2.26540e-01  1.21284e+05 -2.44160e+00]
#   ...
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]
#   [-9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03 -9.00000e+03]]]

# %%
columns_sorted = []

for i in range (1,16):
    columns_sorted.append( 'jet' + str(i) + '_pt' )
    columns_sorted.append( 'jet' + str(i) + '_eta' )
    columns_sorted.append( 'jet' + str(i) + '_phi' )
    columns_sorted.append( 'jet' + str(i) + '_E' )
    columns_sorted.append( 'jet' + str(i) + '_DL1R' )

# %%
data_sorted_DL1R = pd.DataFrame(data_array_r.reshape(111310, 75), columns = columns_sorted)

# %%
data_sorted_DL1R
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       111925.0 -1.866030  3.085620  370719.0   9.601090  244599.0 -2.590770
# 1       113569.0 -0.526400 -1.441500  129917.0   4.693190   39071.3 -1.771810
# 2        43541.4  0.711012  1.897830   55425.9   5.737620  123003.0 -0.615800
# 3        88992.7  0.670236 -1.658600  110748.0   8.914730   36598.6  1.108590
# 4       337068.0 -0.855149 -1.318100  469178.0   8.574970  114119.0  0.884803
# ...          ...       ...       ...       ...        ...       ...       ...
# 111305   47528.4  0.539272  1.867090   55095.0  -0.638871   40677.3  1.507070
# 111306   36505.5 -1.800650 -0.753436  113660.0   2.269720   83327.8 -1.129970
# 111307  109837.0  1.735830  0.043495  321476.0   2.028460   50853.1  0.772852
# 111308   29616.2  1.586940  2.783880   75629.3   8.752850   31426.0 -2.468970
# 111309   85337.6  0.308503  0.558505   90091.2   8.097930   49027.2  2.644450
#
#         jet2_phi     jet2_E  jet2_DL1R  ...  jet14_pt  jet14_eta  jet14_phi  \
# 0      -3.063440  1640840.0  -1.031460  ...   -9000.0    -9000.0    -9000.0
# 1      -1.082860   118313.0   0.282053  ...   -9000.0    -9000.0    -9000.0
# 2       2.021560   147629.0  -1.612100  ...   -9000.0    -9000.0    -9000.0
# 3      -1.685520    61847.2   0.756823  ...   -9000.0    -9000.0    -9000.0
# 4      -2.694940   162221.0   5.473240  ...   -9000.0    -9000.0    -9000.0
# ...          ...        ...        ...  ...       ...        ...        ...
# 111305  0.121815    96737.3  -1.984430  ...   -9000.0    -9000.0    -9000.0
# 111306  2.671090   143007.0  -2.038660  ...   -9000.0    -9000.0    -9000.0
# 111307  2.425470    67413.6  -1.663980  ...   -9000.0    -9000.0    -9000.0
# 111308 -2.327310   186996.0  -0.818002  ...   -9000.0    -9000.0    -9000.0
# 111309  2.154280   346837.0  -2.211860  ...   -9000.0    -9000.0    -9000.0
#
#         jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  jet15_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 111305  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111306  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111307  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111308  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111309  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet15_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 111305     -9000.0
# 111306     -9000.0
# 111307     -9000.0
# 111308     -9000.0
# 111309     -9000.0
#
# [111310 rows x 75 columns]

# %%
######### Just sort by DL1R

# %%
tH_gamgam_sorted = photons.join(data_sorted_DL1R)
tH_gamgam_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E     y2_pt    y2_eta    y2_phi  \
# 0       390375.0 -0.547024  0.022353  450253.0   88331.8 -1.196040 -0.110091
# 1        88909.4 -1.707230  1.613110  253171.0   36525.8 -0.128228  2.990240
# 2       236877.0  1.705330 -0.967860  673312.0   42001.2  0.576428 -1.403090
# 3       168441.0 -1.783590  1.083770  515366.0   46945.1 -1.366870  2.594060
# 4       384296.0  0.165686  0.932733  389583.0  281261.0 -0.092400  0.652804
# ...          ...       ...       ...       ...       ...       ...       ...
# 111305  126436.0 -0.646720 -1.864920  153811.0   31523.1 -0.998545  1.815580
# 111306  101824.0  0.235308  0.018492  104656.0   50372.3 -0.009167 -2.157660
# 111307   72512.1  0.265093 -2.506930   75074.9   68986.0  1.779620 -1.822220
# 111308  125397.0  1.746290  1.189130  370404.0   58541.7  1.572810 -0.466225
# 111309  205179.0 -1.342500  2.760900  419568.0   76309.0 -0.450990 -3.103890
#
#             y2_E  Njets   jet1_pt  ...  jet14_pt  jet14_eta  jet14_phi  \
# 0       159411.0      4  111925.0  ...   -9000.0    -9000.0    -9000.0
# 1        36826.5      4  113569.0  ...   -9000.0    -9000.0    -9000.0
# 2        49174.4      5   43541.4  ...   -9000.0    -9000.0    -9000.0
# 3        98066.9      3   88992.7  ...   -9000.0    -9000.0    -9000.0
# 4       282462.0      5  337068.0  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 111305   48588.8      3   47528.4  ...   -9000.0    -9000.0    -9000.0
# 111306   50374.4      4   36505.5  ...   -9000.0    -9000.0    -9000.0
# 111307  210279.0      3  109837.0  ...   -9000.0    -9000.0    -9000.0
# 111308  147164.0      3   29616.2  ...   -9000.0    -9000.0    -9000.0
# 111309   84201.8      5   85337.6  ...   -9000.0    -9000.0    -9000.0
#
#         jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  jet15_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 111305  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111306  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111307  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111308  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111309  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet15_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 111305     -9000.0
# 111306     -9000.0
# 111307     -9000.0
# 111308     -9000.0
# 111309     -9000.0
#
# [111310 rows x 84 columns]

# %%
tH_gamgam_sorted.to_csv('tH_gamgam_SDL1R.csv', index = True)

# %%
#########

# %%
b_jet_data = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(5, 75)], axis=1)

# %% [markdown]
# ### Jets with highest DL1R values (b quarks)

# %%
b_jet_data
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R
# 0       111925.0 -1.866030  3.085620  370719.0   9.601090
# 1       113569.0 -0.526400 -1.441500  129917.0   4.693190
# 2        43541.4  0.711012  1.897830   55425.9   5.737620
# 3        88992.7  0.670236 -1.658600  110748.0   8.914730
# 4       337068.0 -0.855149 -1.318100  469178.0   8.574970
# ...          ...       ...       ...       ...        ...
# 111305   47528.4  0.539272  1.867090   55095.0  -0.638871
# 111306   36505.5 -1.800650 -0.753436  113660.0   2.269720
# 111307  109837.0  1.735830  0.043495  321476.0   2.028460
# 111308   29616.2  1.586940  2.783880   75629.3   8.752850
# 111309   85337.6  0.308503  0.558505   90091.2   8.097930
#
# [111310 rows x 5 columns]

# %% [markdown]
# # Sort the remaining jets by decreasing pt again

# %%
other_jets = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(0, 5)], axis=1)

# %%
other_jets
# Out:
#          jet2_pt  jet2_eta  jet2_phi     jet2_E  jet2_DL1R   jet3_pt  \
# 0       244599.0 -2.590770 -3.063440  1640840.0  -1.031460  174304.0
# 1        39071.3 -1.771810 -1.082860   118313.0   0.282053   36968.3
# 2       123003.0 -0.615800  2.021560   147629.0  -1.612100   81069.9
# 3        36598.6  1.108590 -1.685520    61847.2   0.756823   34273.6
# 4       114119.0  0.884803 -2.694940   162221.0   5.473240  295253.0
# ...          ...       ...       ...        ...        ...       ...
# 111305   40677.3  1.507070  0.121815    96737.3  -1.984430   32978.9
# 111306   83327.8 -1.129970  2.671090   143007.0  -2.038660   36209.3
# 111307   50853.1  0.772852  2.425470    67413.6  -1.663980   68698.4
# 111308   31426.0 -2.468970 -2.327310   186996.0  -0.818002   89642.8
# 111309   49027.2  2.644450  2.154280   346837.0  -2.211860  109844.0
#
#         jet3_eta  jet3_phi    jet3_E  jet3_DL1R  ...  jet14_pt  jet14_eta  \
# 0      -2.286610  2.870830  866922.0   -2.67018  ...   -9000.0    -9000.0
# 1       2.067520  1.783090  148562.0   -3.05691  ...   -9000.0    -9000.0
# 2      -1.493160 -2.628350  190034.0   -1.89234  ...   -9000.0    -9000.0
# 3      -0.493756 -2.709040   38858.8   -3.34632  ...   -9000.0    -9000.0
# 4       1.501440 -2.842200  697234.0   -2.72969  ...   -9000.0    -9000.0
# ...          ...       ...       ...        ...  ...       ...        ...
# 111305  0.398328  1.208290   36172.4   -2.40373  ...   -9000.0    -9000.0
# 111306  3.396190  0.255047  541076.0   -2.21453  ...   -9000.0    -9000.0
# 111307  0.916289  0.285153   99945.5   -2.37483  ...   -9000.0    -9000.0
# 111308  0.098086 -2.147140   90266.9   -3.00431  ...   -9000.0    -9000.0
# 111309 -0.448321 -0.226540  121284.0   -2.44160  ...   -9000.0    -9000.0
#
#         jet14_phi  jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  \
# 0         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 1         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 2         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 3         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 4         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# ...           ...      ...         ...       ...        ...        ...
# 111305    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111306    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111307    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111308    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111309    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
#
#         jet15_E  jet15_DL1R
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 111305  -9000.0     -9000.0
# 111306  -9000.0     -9000.0
# 111307  -9000.0     -9000.0
# 111308  -9000.0     -9000.0
# 111309  -9000.0     -9000.0
#
# [111310 rows x 70 columns]

# %%
oth_jets_array = other_jets.values.reshape(111310, 14, 5)

# %%
for i in range(111310):
    oth_jets_array[i] = oth_jets_array[i, :, :][oth_jets_array[i, :, 0].argsort()[::-1]]

# %%
oth_jets_sorted = pd.DataFrame(oth_jets_array.reshape(111310, 70), columns = columns_sorted[5:])

# %%
oth_jets_sorted
# Out:
#          jet2_pt  jet2_eta  jet2_phi     jet2_E  jet2_DL1R   jet3_pt  \
# 0       244599.0 -2.590770 -3.063440  1640840.0  -1.031460  174304.0
# 1        54133.2  0.426996  1.809370    59619.7  -3.269760   39071.3
# 2       123003.0 -0.615800  2.021560   147629.0  -1.612100  122165.0
# 3        36598.6  1.108590 -1.685520    61847.2   0.756823   34273.6
# 4       295253.0  1.501440 -2.842200   697234.0  -2.729690  114119.0
# ...          ...       ...       ...        ...        ...       ...
# 111305   40677.3  1.507070  0.121815    96737.3  -1.984430   32978.9
# 111306   83327.8 -1.129970  2.671090   143007.0  -2.038660   59241.5
# 111307   68698.4  0.916289  0.285153    99945.5  -2.374830   50853.1
# 111308   89642.8  0.098086 -2.147140    90266.9  -3.004310   31426.0
# 111309  119254.0  0.106681 -0.631169   121036.0  -4.518370  109844.0
#
#         jet3_eta  jet3_phi    jet3_E  jet3_DL1R  ...  jet14_pt  jet14_eta  \
# 0      -2.286610   2.87083  866922.0  -2.670180  ...   -9000.0    -9000.0
# 1      -1.771810  -1.08286  118313.0   0.282053  ...   -9000.0    -9000.0
# 2      -0.013600   2.08382  122319.0  -5.907740  ...   -9000.0    -9000.0
# 3      -0.493756  -2.70904   38858.8  -3.346320  ...   -9000.0    -9000.0
# 4       0.884803  -2.69494  162221.0   5.473240  ...   -9000.0    -9000.0
# ...          ...       ...       ...        ...  ...       ...        ...
# 111305  0.398328   1.20829   36172.4  -2.403730  ...   -9000.0    -9000.0
# 111306 -1.462060  -2.93431  135388.0  -2.926370  ...   -9000.0    -9000.0
# 111307  0.772852   2.42547   67413.6  -1.663980  ...   -9000.0    -9000.0
# 111308 -2.468970  -2.32731  186996.0  -0.818002  ...   -9000.0    -9000.0
# 111309 -0.448321  -0.22654  121284.0  -2.441600  ...   -9000.0    -9000.0
#
#         jet14_phi  jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  \
# 0         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 1         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 2         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 3         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 4         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# ...           ...      ...         ...       ...        ...        ...
# 111305    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111306    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111307    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111308    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111309    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
#
#         jet15_E  jet15_DL1R
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 111305  -9000.0     -9000.0
# 111306  -9000.0     -9000.0
# 111307  -9000.0     -9000.0
# 111308  -9000.0     -9000.0
# 111309  -9000.0     -9000.0
#
# [111310 rows x 70 columns]

# %% [markdown]
# # Join together the two data frames

# %%
b_jet_data
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R
# 0       111925.0 -1.866030  3.085620  370719.0   9.601090
# 1       113569.0 -0.526400 -1.441500  129917.0   4.693190
# 2        43541.4  0.711012  1.897830   55425.9   5.737620
# 3        88992.7  0.670236 -1.658600  110748.0   8.914730
# 4       337068.0 -0.855149 -1.318100  469178.0   8.574970
# ...          ...       ...       ...       ...        ...
# 111305   47528.4  0.539272  1.867090   55095.0  -0.638871
# 111306   36505.5 -1.800650 -0.753436  113660.0   2.269720
# 111307  109837.0  1.735830  0.043495  321476.0   2.028460
# 111308   29616.2  1.586940  2.783880   75629.3   8.752850
# 111309   85337.6  0.308503  0.558505   90091.2   8.097930
#
# [111310 rows x 5 columns]

# %%
oth_jets_sorted
# Out:
#          jet2_pt  jet2_eta  jet2_phi     jet2_E  jet2_DL1R   jet3_pt  \
# 0       244599.0 -2.590770 -3.063440  1640840.0  -1.031460  174304.0
# 1        54133.2  0.426996  1.809370    59619.7  -3.269760   39071.3
# 2       123003.0 -0.615800  2.021560   147629.0  -1.612100  122165.0
# 3        36598.6  1.108590 -1.685520    61847.2   0.756823   34273.6
# 4       295253.0  1.501440 -2.842200   697234.0  -2.729690  114119.0
# ...          ...       ...       ...        ...        ...       ...
# 111305   40677.3  1.507070  0.121815    96737.3  -1.984430   32978.9
# 111306   83327.8 -1.129970  2.671090   143007.0  -2.038660   59241.5
# 111307   68698.4  0.916289  0.285153    99945.5  -2.374830   50853.1
# 111308   89642.8  0.098086 -2.147140    90266.9  -3.004310   31426.0
# 111309  119254.0  0.106681 -0.631169   121036.0  -4.518370  109844.0
#
#         jet3_eta  jet3_phi    jet3_E  jet3_DL1R  ...  jet14_pt  jet14_eta  \
# 0      -2.286610   2.87083  866922.0  -2.670180  ...   -9000.0    -9000.0
# 1      -1.771810  -1.08286  118313.0   0.282053  ...   -9000.0    -9000.0
# 2      -0.013600   2.08382  122319.0  -5.907740  ...   -9000.0    -9000.0
# 3      -0.493756  -2.70904   38858.8  -3.346320  ...   -9000.0    -9000.0
# 4       0.884803  -2.69494  162221.0   5.473240  ...   -9000.0    -9000.0
# ...          ...       ...       ...        ...  ...       ...        ...
# 111305  0.398328   1.20829   36172.4  -2.403730  ...   -9000.0    -9000.0
# 111306 -1.462060  -2.93431  135388.0  -2.926370  ...   -9000.0    -9000.0
# 111307  0.772852   2.42547   67413.6  -1.663980  ...   -9000.0    -9000.0
# 111308 -2.468970  -2.32731  186996.0  -0.818002  ...   -9000.0    -9000.0
# 111309 -0.448321  -0.22654  121284.0  -2.441600  ...   -9000.0    -9000.0
#
#         jet14_phi  jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  \
# 0         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 1         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 2         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 3         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 4         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# ...           ...      ...         ...       ...        ...        ...
# 111305    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111306    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111307    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111308    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 111309    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
#
#         jet15_E  jet15_DL1R
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 111305  -9000.0     -9000.0
# 111306  -9000.0     -9000.0
# 111307  -9000.0     -9000.0
# 111308  -9000.0     -9000.0
# 111309  -9000.0     -9000.0
#
# [111310 rows x 70 columns]

# %%
jets3 = b_jet_data.join(oth_jets_sorted)

# %%
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       111925.0 -1.866030  3.085620  370719.0   9.601090  244599.0 -2.590770
# 1       113569.0 -0.526400 -1.441500  129917.0   4.693190   54133.2  0.426996
# 2        43541.4  0.711012  1.897830   55425.9   5.737620  123003.0 -0.615800
# 3        88992.7  0.670236 -1.658600  110748.0   8.914730   36598.6  1.108590
# 4       337068.0 -0.855149 -1.318100  469178.0   8.574970  295253.0  1.501440
# ...          ...       ...       ...       ...        ...       ...       ...
# 111305   47528.4  0.539272  1.867090   55095.0  -0.638871   40677.3  1.507070
# 111306   36505.5 -1.800650 -0.753436  113660.0   2.269720   83327.8 -1.129970
# 111307  109837.0  1.735830  0.043495  321476.0   2.028460   68698.4  0.916289
# 111308   29616.2  1.586940  2.783880   75629.3   8.752850   89642.8  0.098086
# 111309   85337.6  0.308503  0.558505   90091.2   8.097930  119254.0  0.106681
#
#         jet2_phi     jet2_E  jet2_DL1R  ...  jet14_pt  jet14_eta  jet14_phi  \
# 0      -3.063440  1640840.0  -1.031460  ...   -9000.0    -9000.0    -9000.0
# 1       1.809370    59619.7  -3.269760  ...   -9000.0    -9000.0    -9000.0
# 2       2.021560   147629.0  -1.612100  ...   -9000.0    -9000.0    -9000.0
# 3      -1.685520    61847.2   0.756823  ...   -9000.0    -9000.0    -9000.0
# 4      -2.842200   697234.0  -2.729690  ...   -9000.0    -9000.0    -9000.0
# ...          ...        ...        ...  ...       ...        ...        ...
# 111305  0.121815    96737.3  -1.984430  ...   -9000.0    -9000.0    -9000.0
# 111306  2.671090   143007.0  -2.038660  ...   -9000.0    -9000.0    -9000.0
# 111307  0.285153    99945.5  -2.374830  ...   -9000.0    -9000.0    -9000.0
# 111308 -2.147140    90266.9  -3.004310  ...   -9000.0    -9000.0    -9000.0
# 111309 -0.631169   121036.0  -4.518370  ...   -9000.0    -9000.0    -9000.0
#
#         jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  jet15_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 111305  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111306  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111307  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111308  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111309  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet15_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 111305     -9000.0
# 111306     -9000.0
# 111307     -9000.0
# 111308     -9000.0
# 111309     -9000.0
#
# [111310 rows x 75 columns]

# %%
shape1 = jets3.shape[0]

# %% [markdown]
# # Make csv file

# %%
tH_gamgam_sorted = photons.join(jets3)
tH_gamgam_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E     y2_pt    y2_eta    y2_phi  \
# 0       390375.0 -0.547024  0.022353  450253.0   88331.8 -1.196040 -0.110091
# 1        88909.4 -1.707230  1.613110  253171.0   36525.8 -0.128228  2.990240
# 2       236877.0  1.705330 -0.967860  673312.0   42001.2  0.576428 -1.403090
# 3       168441.0 -1.783590  1.083770  515366.0   46945.1 -1.366870  2.594060
# 4       384296.0  0.165686  0.932733  389583.0  281261.0 -0.092400  0.652804
# ...          ...       ...       ...       ...       ...       ...       ...
# 111305  126436.0 -0.646720 -1.864920  153811.0   31523.1 -0.998545  1.815580
# 111306  101824.0  0.235308  0.018492  104656.0   50372.3 -0.009167 -2.157660
# 111307   72512.1  0.265093 -2.506930   75074.9   68986.0  1.779620 -1.822220
# 111308  125397.0  1.746290  1.189130  370404.0   58541.7  1.572810 -0.466225
# 111309  205179.0 -1.342500  2.760900  419568.0   76309.0 -0.450990 -3.103890
#
#             y2_E  Njets   jet1_pt  ...  jet14_pt  jet14_eta  jet14_phi  \
# 0       159411.0      4  111925.0  ...   -9000.0    -9000.0    -9000.0
# 1        36826.5      4  113569.0  ...   -9000.0    -9000.0    -9000.0
# 2        49174.4      5   43541.4  ...   -9000.0    -9000.0    -9000.0
# 3        98066.9      3   88992.7  ...   -9000.0    -9000.0    -9000.0
# 4       282462.0      5  337068.0  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 111305   48588.8      3   47528.4  ...   -9000.0    -9000.0    -9000.0
# 111306   50374.4      4   36505.5  ...   -9000.0    -9000.0    -9000.0
# 111307  210279.0      3  109837.0  ...   -9000.0    -9000.0    -9000.0
# 111308  147164.0      3   29616.2  ...   -9000.0    -9000.0    -9000.0
# 111309   84201.8      5   85337.6  ...   -9000.0    -9000.0    -9000.0
#
#         jet14_E  jet14_DL1R  jet15_pt  jet15_eta  jet15_phi  jet15_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 111305  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111306  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111307  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111308  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 111309  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet15_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 111305     -9000.0
# 111306     -9000.0
# 111307     -9000.0
# 111308     -9000.0
# 111309     -9000.0
#
# [111310 rows x 84 columns]

# %%
tH_gamgam_sorted.to_csv('th_gamgam_sorted.csv', index = True)

# %% [markdown]
# ### Make cut?

# %%
jets3.describe()['jet1_DL1R'][['min', 'max']]
# Out:
# min    -4.38247
# max    15.54260
# Name: jet1_DL1R, dtype: float64

# %%
jets3.describe()['jet2_DL1R'][['min', 'max']]
# Out:
# min    -9.02773
# max    11.35450
# Name: jet2_DL1R, dtype: float64

# %%
jets3.describe()['jet3_DL1R'][['min', 'max']]
# Out:
# min    -6.37791
# max    11.00290
# Name: jet3_DL1R, dtype: float64

# %%
jets3 = jets3.loc[jets3['jet1_DL1R'] > 0]

# %%
shape2 = jets3.shape[0]

# %%
print ((shape2/shape1) * 100)
# Out:
# 80.5812595454137

# %% [markdown]
# # Four momentum

# %%
def fomjets(x, num):
    
    string = 'jet' + str(num) + '_'
    E = x[string + 'E']
    px = abs(x[string + 'pt']) * np.cos(x[string + 'phi'])
    py = abs(x[string + 'pt']) * np.sin(x[string + 'phi'])
    pz = x[string + 'pt']/(np.tan(2*np.arctan(np.exp(-x[string + 'eta']))))

    return np.array([E, px, py, pz])

# %%
for i in range (1,4):
    
    jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# Out:
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_14692\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_14692\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_14692\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)

# %%
jets3 = jets3.assign(quark_fom = jets3.jet1_fom + jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3 = jets3.assign(wboson_fom = jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       111925.0 -1.866030  3.085620  370719.0    9.60109  244599.0 -2.590770
# 1       113569.0 -0.526400 -1.441500  129917.0    4.69319   54133.2  0.426996
# 2        43541.4  0.711012  1.897830   55425.9    5.73762  123003.0 -0.615800
# 3        88992.7  0.670236 -1.658600  110748.0    8.91473   36598.6  1.108590
# 4       337068.0 -0.855149 -1.318100  469178.0    8.57497  295253.0  1.501440
# ...          ...       ...       ...       ...        ...       ...       ...
# 111304  218229.0 -0.845383  1.427410  302662.0    8.08926  194175.0  1.589210
# 111306   36505.5 -1.800650 -0.753436  113660.0    2.26972   83327.8 -1.129970
# 111307  109837.0  1.735830  0.043495  321476.0    2.02846   68698.4  0.916289
# 111308   29616.2  1.586940  2.783880   75629.3    8.75285   89642.8  0.098086
# 111309   85337.6  0.308503  0.558505   90091.2    8.09793  119254.0  0.106681
#
#         jet2_phi     jet2_E  jet2_DL1R  ...  jet15_pt  jet15_eta  jet15_phi  \
# 0      -3.063440  1640840.0  -1.031460  ...   -9000.0    -9000.0    -9000.0
# 1       1.809370    59619.7  -3.269760  ...   -9000.0    -9000.0    -9000.0
# 2       2.021560   147629.0  -1.612100  ...   -9000.0    -9000.0    -9000.0
# 3      -1.685520    61847.2   0.756823  ...   -9000.0    -9000.0    -9000.0
# 4      -2.842200   697234.0  -2.729690  ...   -9000.0    -9000.0    -9000.0
# ...          ...        ...        ...  ...       ...        ...        ...
# 111304 -0.877494   496339.0  -3.267930  ...   -9000.0    -9000.0    -9000.0
# 111306  2.671090   143007.0  -2.038660  ...   -9000.0    -9000.0    -9000.0
# 111307  0.285153    99945.5  -2.374830  ...   -9000.0    -9000.0    -9000.0
# 111308 -2.147140    90266.9  -3.004310  ...   -9000.0    -9000.0    -9000.0
# 111309 -0.631169   121036.0  -4.518370  ...   -9000.0    -9000.0    -9000.0
#
#         jet15_E  jet15_DL1R  \
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 111304  -9000.0     -9000.0
# 111306  -9000.0     -9000.0
# 111307  -9000.0     -9000.0
# 111308  -9000.0     -9000.0
# 111309  -9000.0     -9000.0
#
#                                                  jet1_fom  \
# 0       [370719.0, -111749.71872926113, 6261.468592193...
# 1       [129917.0, 14643.175177702338, -112621.0245989...
# 2       [55425.9, -13987.0362639611, 41233.6795655037,...
# 3       [110748.0, -7803.849645168826, -88649.87639024...
# 4       [469178.0, 84272.24520906848, -326363.33328274...
# ...                                                   ...
# 111304  [302662.0, 31183.94274863783, 215989.486215532...
# 111306  [113660.0, 26625.01057165083, -24975.194539972...
# 111307  [321476.0, 109733.12168996359, 4775.8321971820...
# 111308  [75629.3, -27741.498920084538, 10369.596911497...
# 111309  [90091.2, 72370.40551934771, 45222.01210389877...
#
#                                                  jet2_fom  \
# 0       [1640840.0, -243852.39468469948, -19096.607225...
# 1       [59619.7, -12792.59216149031, 52599.9327759054...
# 2       [147629.0, -53586.63266682483, 110716.80454398...
# 3       [61847.2, -4189.521615498785, -36358.017418353...
# 4       [697234.0, -282118.9053323059, -87081.89974444...
# ...                                                   ...
# 111304  [496339.0, 124093.47805693885, -149347.7128339...
# 111306  [143007.0, -74273.44547037207, 37775.356395402...
# 111307  [99945.5, 65924.26410202662, 19325.15369062414...
# 111308  [90266.9, -48851.9105752335, -75161.9745948002...
# 111309  [121036.0, 96278.31520489349, -70370.466371249...
#
#                                                  jet3_fom  \
# 0       [866922.0, -167953.61590650032, 46620.46031445...
# 1       [118313.0, 18316.783313343665, -34511.76513512...
# 2       [122319.0, -59960.28075827998, 106438.01931823...
# 3       [38858.8, -31116.955604306946, -14367.14066471...
# 4       [162221.0, -102923.70189327157, -49293.5873069...
# ...                                                   ...
# 111304  [1047320.0, 18264.068915414162, -155529.281457...
# 111306  [135388.0, -57973.36228716094, -12191.98865532...
# 111307  [67413.6, -38361.37844393973, 33383.2656205296...
# 111308  [186996.0, -21570.499942719165, -22854.0370223...
# 111309  [121284.0, 107037.41632327938, -24671.76205375...
#
#                                                 quark_fom  \
# 0       [2878481.0, -523555.72932046093, 33785.3216808...
# 1       [307849.7, 20167.36632955569, -94532.856958159...
# 2       [325373.9, -127533.94968906592, 258388.5034277...
# 3       [211454.0, -43110.32686497456, -139375.0344733...
# 4       [1328633.0, -300770.362016509, -462738.8203341...
# ...                                                   ...
# 111304  [1846321.0, 173541.48972099085, -88887.5080758...
# 111306  [392055.0, -105621.79718588218, 608.1732001042...
# 111307  [488835.1, 137296.00734805048, 57484.251508335...
# 111308  [352892.2, -98163.90943803721, -87646.41470570...
# 111309  [332411.2, 275686.1370475206, -49820.216321103...
#
#                                                wboson_fom
# 0       [2507762.0, -411806.0105911998, 27523.85308862...
# 1       [177932.7, 5524.191151853354, 18088.1676407806...
# 2       [269948.0, -113546.91342510481, 217154.8238622...
# 3       [100706.0, -35306.47721980573, -50725.15808306...
# 4       [859455.0, -385042.60722557746, -136375.487051...
# ...                                                   ...
# 111304  [1543659.0, 142357.546972353, -304876.99429134...
# 111306  [278395.0, -132246.807757533, 25583.3677400768...
# 111307  [167359.1, 27562.88565808689, 52708.4193111537...
# 111308  [277262.9, -70422.41051795267, -98016.01161719...
# 111309  [242320.0, 203315.73152817285, -95042.22842500...
#
# [89695 rows x 80 columns]

# %% [markdown]
# # Plot mass distributions

# %%
quark_m = []

for row in jets3.quark_fom:
    quark_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(quark_m, bins = 5000, color = 'blue')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('Quark Mass');

# %%
arg = np.argmax(n)
print (bins[arg])
# Out:
# 168.94740650843755

# %%
wboson_m = []

for row in jets3.wboson_fom:
    wboson_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(wboson_m, bins = 5000, color = 'green')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('W boson Mass');

# %%
arg = np.argmax(n)
print (bins[arg])
# Out:
# 79.60359423694575

# %% [markdown]
# ## DL1R of 1st three jets

# %%
dl1rs = np.array([])

for i in range(1,4):
    string = 'jet' + str(i) + '_DL1R'
    array = np.array(jets3[string])
    dl1rs = np.append(dl1rs, array)

# %%
plt.hist(dl1rs, bins = 300, color = 'blue')
plt.xlabel('jet DL1R')
plt.ylabel('Counts');

# %% [markdown]
# ## DL1R of first jet (b quark?)

# %%
plt.hist(jets3.jet1_DL1R, bins = 300, color = 'blue')
plt.xlabel('jet DL1R')
plt.ylabel('Counts');

# %% [markdown]
# ## Pt of first three jets

# %%
pts = np.array([])

for i in range(1,4):
    string = 'jet' + str(i) + '_pt'
    array = np.array(jets3[string])
    pts = np.append(pts, array)

# %%
n, bins, patches = plt.hist(pts, bins = 1000, color = 'blue', alpha = 0.8)
plt.xlabel('jet pt')
plt.xlim(0, 0.5*1e6)
plt.ylabel('Counts');

# %% [markdown]
# ## E of first three jets

# %%
Es = np.array([])

for i in range(1,4):
    string = 'jet' + str(i) + '_E'
    array = np.array(jets3[string])
    Es = np.append(Es, array)

# %%
n, bins, patches = plt.hist(Es, bins = 1000, color = 'blue', alpha = 0.8)
plt.xlabel('jet E')
plt.xlim(0, 0.5*1e6)
plt.ylabel('Counts');

# %% [markdown]
# ## 2nd jet

# %%
plt.hist(jets3.jet2_DL1R, bins = 500, color = 'blue');

# %%
plt.hist(data_sorted_DL1R.jet2_DL1R, bins = 500, color = 'blue');

# %%
second_jet = []

for row in jets3.jet2_fom:
    second_jet.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(second_jet, bins = 5000, color = 'blue')
plt.xlim(0, 100)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('Jet Mass');
# Out:
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_14692\3073852785.py:4: RuntimeWarning: invalid value encountered in sqrt
#   second_jet.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

# %%
arg = np.argmax(n)
print (bins[arg])
# Out:
# 7.193242618445273

# %%
for i in range (1,4):
    
    data_sorted_DL1R['jet' + str(i) + '_fom'] = data_sorted_DL1R.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)

# %%
data_sorted_DL1R
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       111925.0 -1.866030  3.085620  370719.0   9.601090  244599.0 -2.590770
# 1       113569.0 -0.526400 -1.441500  129917.0   4.693190   39071.3 -1.771810
# 2        43541.4  0.711012  1.897830   55425.9   5.737620  123003.0 -0.615800
# 3        88992.7  0.670236 -1.658600  110748.0   8.914730   36598.6  1.108590
# 4       337068.0 -0.855149 -1.318100  469178.0   8.574970  114119.0  0.884803
# ...          ...       ...       ...       ...        ...       ...       ...
# 111305   47528.4  0.539272  1.867090   55095.0  -0.638871   40677.3  1.507070
# 111306   36505.5 -1.800650 -0.753436  113660.0   2.269720   83327.8 -1.129970
# 111307  109837.0  1.735830  0.043495  321476.0   2.028460   50853.1  0.772852
# 111308   29616.2  1.586940  2.783880   75629.3   8.752850   31426.0 -2.468970
# 111309   85337.6  0.308503  0.558505   90091.2   8.097930   49027.2  2.644450
#
#         jet2_phi     jet2_E  jet2_DL1R  ...  jet14_E  jet14_DL1R  jet15_pt  \
# 0      -3.063440  1640840.0  -1.031460  ...  -9000.0     -9000.0   -9000.0
# 1      -1.082860   118313.0   0.282053  ...  -9000.0     -9000.0   -9000.0
# 2       2.021560   147629.0  -1.612100  ...  -9000.0     -9000.0   -9000.0
# 3      -1.685520    61847.2   0.756823  ...  -9000.0     -9000.0   -9000.0
# 4      -2.694940   162221.0   5.473240  ...  -9000.0     -9000.0   -9000.0
# ...          ...        ...        ...  ...      ...         ...       ...
# 111305  0.121815    96737.3  -1.984430  ...  -9000.0     -9000.0   -9000.0
# 111306  2.671090   143007.0  -2.038660  ...  -9000.0     -9000.0   -9000.0
# 111307  2.425470    67413.6  -1.663980  ...  -9000.0     -9000.0   -9000.0
# 111308 -2.327310   186996.0  -0.818002  ...  -9000.0     -9000.0   -9000.0
# 111309  2.154280   346837.0  -2.211860  ...  -9000.0     -9000.0   -9000.0
#
#         jet15_eta  jet15_phi  jet15_E  jet15_DL1R  \
# 0         -9000.0    -9000.0  -9000.0     -9000.0
# 1         -9000.0    -9000.0  -9000.0     -9000.0
# 2         -9000.0    -9000.0  -9000.0     -9000.0
# 3         -9000.0    -9000.0  -9000.0     -9000.0
# 4         -9000.0    -9000.0  -9000.0     -9000.0
# ...           ...        ...      ...         ...
# 111305    -9000.0    -9000.0  -9000.0     -9000.0
# 111306    -9000.0    -9000.0  -9000.0     -9000.0
# 111307    -9000.0    -9000.0  -9000.0     -9000.0
# 111308    -9000.0    -9000.0  -9000.0     -9000.0
# 111309    -9000.0    -9000.0  -9000.0     -9000.0
#
#                                                  jet1_fom  \
# 0       [370719.0, -111749.71872926113, 6261.468592193...
# 1       [129917.0, 14643.175177702338, -112621.0245989...
# 2       [55425.9, -13987.0362639611, 41233.6795655037,...
# 3       [110748.0, -7803.849645168826, -88649.87639024...
# 4       [469178.0, 84272.24520906848, -326363.33328274...
# ...                                                   ...
# 111305  [55095.0, -13877.218457724119, 45457.360398912...
# 111306  [113660.0, 26625.01057165083, -24975.194539972...
# 111307  [321476.0, 109733.12168996359, 4775.8321971820...
# 111308  [75629.3, -27741.498920084538, 10369.596911497...
# 111309  [90091.2, 72370.40551934771, 45222.01210389877...
#
#                                                  jet2_fom  \
# 0       [1640840.0, -243852.39468469948, -19096.607225...
# 1       [118313.0, 18316.783313343665, -34511.76513512...
# 2       [147629.0, -53586.63266682483, 110716.80454398...
# 3       [61847.2, -4189.521615498785, -36358.017418353...
# 4       [162221.0, -102923.70189327157, -49293.5873069...
# ...                                                   ...
# 111305  [96737.3, 40375.869941416284, 4942.85967470628...
# 111306  [143007.0, -74273.44547037207, 37775.356395402...
# 111307  [67413.6, -38361.37844393973, 33383.2656205296...
# 111308  [186996.0, -21570.499942719165, -22854.0370223...
# 111309  [346837.0, -27010.77925314977, 40915.573367333...
#
#                                                  jet3_fom
# 0       [866922.0, -167953.61590650032, 46620.46031445...
# 1       [148562.0, -7789.31814143664, 36138.3691909511...
# 2       [190034.0, -70624.60539023482, -39805.70059028...
# 3       [38858.8, -31116.955604306946, -14367.14066471...
# 4       [697234.0, -282118.9053323059, -87081.89974444...
# ...                                                   ...
# 111305  [36172.4, 11694.937536702826, 30835.6333034140...
# 111306  [541076.0, 35037.98125328186, 9135.27647007299...
# 111307  [99945.5, 65924.26410202662, 19325.15369062414...
# 111308  [90266.9, -48851.9105752335, -75161.9745948002...
# 111309  [121284.0, 107037.41632327938, -24671.76205375...
#
# [111310 rows x 78 columns]

# %%
second_jet = []

for row in data_sorted_DL1R.jet2_fom:
    second_jet.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(second_jet, bins = 5000, color = 'blue')
plt.xlim(0, 40)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('Jet Mass');
# Out:
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_14692\2847200989.py:4: RuntimeWarning: invalid value encountered in sqrt
#   second_jet.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

# %%
arg = np.argmax(n)
print (bins[arg])
# Out:
# 5.991204649895782
