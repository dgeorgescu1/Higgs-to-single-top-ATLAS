# %% [markdown]
# # Open data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from iminuit import Minuit
from scipy import integrate

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6) # inches
plt.rcParams['font.size'] = 9

# %%
columns = ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E', 'Njets']
for i in range (1,32):
    columns.append( 'jet' + str(i) + '_pt' )
    columns.append( 'jet' + str(i) + '_eta' )
    columns.append( 'jet' + str(i) + '_phi' )
    columns.append( 'jet' + str(i) + '_E' )
    columns.append( 'jet' + str(i) + '_DL1R' )
    
print (columns)
# Out:
# ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E', 'Njets', 'jet1_pt', 'jet1_eta', 'jet1_phi', 'jet1_E', 'jet1_DL1R', 'jet2_pt', 'jet2_eta', 'jet2_phi', 'jet2_E', 'jet2_DL1R', 'jet3_pt', 'jet3_eta', 'jet3_phi', 'jet3_E', 'jet3_DL1R', 'jet4_pt', 'jet4_eta', 'jet4_phi', 'jet4_E', 'jet4_DL1R', 'jet5_pt', 'jet5_eta', 'jet5_phi', 'jet5_E', 'jet5_DL1R', 'jet6_pt', 'jet6_eta', 'jet6_phi', 'jet6_E', 'jet6_DL1R', 'jet7_pt', 'jet7_eta', 'jet7_phi', 'jet7_E', 'jet7_DL1R', 'jet8_pt', 'jet8_eta', 'jet8_phi', 'jet8_E', 'jet8_DL1R', 'jet9_pt', 'jet9_eta', 'jet9_phi', 'jet9_E', 'jet9_DL1R', 'jet10_pt', 'jet10_eta', 'jet10_phi', 'jet10_E', 'jet10_DL1R', 'jet11_pt', 'jet11_eta', 'jet11_phi', 'jet11_E', 'jet11_DL1R', 'jet12_pt', 'jet12_eta', 'jet12_phi', 'jet12_E', 'jet12_DL1R', 'jet13_pt', 'jet13_eta', 'jet13_phi', 'jet13_E', 'jet13_DL1R', 'jet14_pt', 'jet14_eta', 'jet14_phi', 'jet14_E', 'jet14_DL1R', 'jet15_pt', 'jet15_eta', 'jet15_phi', 'jet15_E', 'jet15_DL1R', 'jet16_pt', 'jet16_eta', 'jet16_phi', 'jet16_E', 'jet16_DL1R', 'jet17_pt', 'jet17_eta', 'jet17_phi', 'jet17_E', 'jet17_DL1R', 'jet18_pt', 'jet18_eta', 'jet18_phi', 'jet18_E', 'jet18_DL1R', 'jet19_pt', 'jet19_eta', 'jet19_phi', 'jet19_E', 'jet19_DL1R', 'jet20_pt', 'jet20_eta', 'jet20_phi', 'jet20_E', 'jet20_DL1R', 'jet21_pt', 'jet21_eta', 'jet21_phi', 'jet21_E', 'jet21_DL1R', 'jet22_pt', 'jet22_eta', 'jet22_phi', 'jet22_E', 'jet22_DL1R', 'jet23_pt', 'jet23_eta', 'jet23_phi', 'jet23_E', 'jet23_DL1R', 'jet24_pt', 'jet24_eta', 'jet24_phi', 'jet24_E', 'jet24_DL1R', 'jet25_pt', 'jet25_eta', 'jet25_phi', 'jet25_E', 'jet25_DL1R', 'jet26_pt', 'jet26_eta', 'jet26_phi', 'jet26_E', 'jet26_DL1R', 'jet27_pt', 'jet27_eta', 'jet27_phi', 'jet27_E', 'jet27_DL1R', 'jet28_pt', 'jet28_eta', 'jet28_phi', 'jet28_E', 'jet28_DL1R', 'jet29_pt', 'jet29_eta', 'jet29_phi', 'jet29_E', 'jet29_DL1R', 'jet30_pt', 'jet30_eta', 'jet30_phi', 'jet30_E', 'jet30_DL1R', 'jet31_pt', 'jet31_eta', 'jet31_phi', 'jet31_E', 'jet31_DL1R']

# %%
data = pd.read_csv('ggf.csv', header = None, names = columns)

# %%
data
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0       114963.0 -2.034150  0.355817  447008.0  42368.2 -2.150490 -1.904770
# 1       117983.0  0.551337  0.540234  136373.0  76804.9  0.196550 -0.815340
# 2       169230.0  0.505756  0.370448  191339.0  79217.6  0.705594  1.491940
# 3        71142.0  0.791507 -0.077236   94614.7  38983.1 -1.129860  0.995488
# 4       172186.0  0.244196  0.668175  177345.0  22768.6  0.106687 -2.687370
# ...          ...       ...       ...       ...      ...       ...       ...
# 474330   61420.3 -0.564030 -1.835940   71451.9  60212.7 -1.136410  1.539250
# 474331  113310.0  0.303105  0.416738  118555.0  29344.7  2.028880  1.519460
# 474332  173313.0 -1.242390  1.128600  325185.0  77625.7 -0.905126  2.191610
# 474333   55301.3  0.485680  2.158840   61952.8  47840.8 -0.817640 -1.377170
# 474334   61309.6  0.390736 -2.801180   66049.7  58066.8  0.894233  0.323046
#
#             y2_E  Njets   jet1_pt  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0       184418.0      3  105040.0  ...       NaN        NaN        NaN
# 1        78293.2      3   55669.8  ...       NaN        NaN        NaN
# 2        99769.2      3  134042.0  ...       NaN        NaN        NaN
# 3        66628.1      3   62210.8  ...       NaN        NaN        NaN
# 4        22898.3      3   94718.6  ...       NaN        NaN        NaN
# ...          ...    ...       ...  ...       ...        ...        ...
# 474330  103461.0      3   37710.9  ...       NaN        NaN        NaN
# 474331  113521.0      4   82349.1  ...       NaN        NaN        NaN
# 474332  111654.0      3  137793.0  ...       NaN        NaN        NaN
# 474333   64743.4      3   83623.9  ...       NaN        NaN        NaN
# 474334   82872.4      5   85825.5  ...       NaN        NaN        NaN
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0           NaN         NaN       NaN        NaN        NaN      NaN
# 1           NaN         NaN       NaN        NaN        NaN      NaN
# 2           NaN         NaN       NaN        NaN        NaN      NaN
# 3           NaN         NaN       NaN        NaN        NaN      NaN
# 4           NaN         NaN       NaN        NaN        NaN      NaN
# ...         ...         ...       ...        ...        ...      ...
# 474330      NaN         NaN       NaN        NaN        NaN      NaN
# 474331      NaN         NaN       NaN        NaN        NaN      NaN
# 474332      NaN         NaN       NaN        NaN        NaN      NaN
# 474333      NaN         NaN       NaN        NaN        NaN      NaN
# 474334      NaN         NaN       NaN        NaN        NaN      NaN
#
#         jet31_DL1R
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 474330         NaN
# 474331         NaN
# 474332         NaN
# 474333         NaN
# 474334         NaN
#
# [474335 rows x 164 columns]

# %%
photons = data.drop(data.columns[np.arange(9, 164)], axis=1)
photons
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0       114963.0 -2.034150  0.355817  447008.0  42368.2 -2.150490 -1.904770
# 1       117983.0  0.551337  0.540234  136373.0  76804.9  0.196550 -0.815340
# 2       169230.0  0.505756  0.370448  191339.0  79217.6  0.705594  1.491940
# 3        71142.0  0.791507 -0.077236   94614.7  38983.1 -1.129860  0.995488
# 4       172186.0  0.244196  0.668175  177345.0  22768.6  0.106687 -2.687370
# ...          ...       ...       ...       ...      ...       ...       ...
# 474330   61420.3 -0.564030 -1.835940   71451.9  60212.7 -1.136410  1.539250
# 474331  113310.0  0.303105  0.416738  118555.0  29344.7  2.028880  1.519460
# 474332  173313.0 -1.242390  1.128600  325185.0  77625.7 -0.905126  2.191610
# 474333   55301.3  0.485680  2.158840   61952.8  47840.8 -0.817640 -1.377170
# 474334   61309.6  0.390736 -2.801180   66049.7  58066.8  0.894233  0.323046
#
#             y2_E  Njets
# 0       184418.0      3
# 1        78293.2      3
# 2        99769.2      3
# 3        66628.1      3
# 4        22898.3      3
# ...          ...    ...
# 474330  103461.0      3
# 474331  113521.0      4
# 474332  111654.0      3
# 474333   64743.4      3
# 474334   82872.4      5
#
# [474335 rows x 9 columns]

# %% [markdown]
# # Plot photon bck (ggf) variables

# %%
fig, axs = plt.subplots(2, 2)

axs[0, 0].hist(data['y1_pt'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_pt')
axs[0, 0].hist(data['y2_pt'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_pt');
axs[0,0].set_xlabel('Momentum (MeV)')
axs[0,0].set_ylabel('Counts')
axs[0,0].set_xlim(0, 0.35e6)
axs[0,0].legend()

axs[0, 1].hist(data['y1_eta'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_eta')
axs[0, 1].hist(data['y2_eta'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_eta');
axs[0,1].set_xlabel('Eta (pseudorapidity)')
axs[0,1].set_ylabel('Counts')
axs[0,1].legend()

axs[1, 0].hist(data['y1_phi'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_phi')
axs[1, 0].hist(data['y2_phi'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_phi');
axs[1,0].set_xlabel('Phi')
axs[1,0].set_ylabel('Counts')
axs[1,0].legend()

axs[1, 1].hist(data['y1_E'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_E')
axs[1, 1].hist(data['y2_E'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_E');
axs[1,1].set_xlabel('Energy (MeV)')
axs[1,1].set_ylabel('Counts')
axs[1,1].set_xlim(0, 0.7e6)
axs[1,1].legend();

# %% [markdown]
# # 4 Mom

# %%
def fomy(x, num):
    
    string = 'y' + str(num) + '_'
    E = x[string + 'E']
    px = abs(x[string + 'pt']) * np.cos(x[string + 'phi'])
    py = abs(x[string + 'pt']) * np.sin(x[string + 'phi'])
    pz = x[string + 'pt']/(np.tan(2*np.arctan(np.exp(-x[string + 'eta']))))

    return np.array([E, px, py, pz])

# %%
data['y1_fom'] = data.apply(lambda x: fomy(x, 1), axis = 1).apply(lambda x: x)
data['y2_fom'] = data.apply(lambda x: fomy(x, 2), axis = 1).apply(lambda x: x)
data = data.assign(H_fom = data.y1_fom + data.y2_fom)

# %% [markdown]
# ## Mass dist.

# %%
H_mass = []

for row in data.H_fom:
    H_mass.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(H_mass, bins = 5000, color = 'gold', density = True)
plt.xlim(80, 180)
plt.xlabel('Mass GeV')
plt.ylabel('Counts');

# %%
H_array = np.array(H_mass)
vals1 = (95 < H_array)
H_array = H_array[vals1]
vals2 = (170 > H_array)
H_array = H_array[vals2]

# %%
plt.hist(H_array, bins = 500, color = 'gold')
plt.xlabel('Mass GeV')
plt.ylabel('Counts');

# %%
data.describe()['Njets'][['min', 'max']]
# Out:
# min     3.0
# max    31.0
# Name: Njets, dtype: float64

# %%
n, bins, patches = plt.hist(data['Njets'], bins = 31, color = 'blue');

# %%
pts = np.array([])

for i in range(1,32):
    string = 'jet' + str(i) + '_pt'
    array = np.array(data[string])
    pts = np.append(pts, array)

# %%
n, bins, patches = plt.hist(pts, bins = 1000, color = 'blue', alpha = 0.8)
plt.xlabel('jet pt')
plt.xlim(0, 0.4*1e6)
plt.ylabel('Counts');

# %%
dl1rs = np.array([])

for i in range(1,32):
    string = 'jet' + str(i) + '_DL1R'
    array = np.array(data[string])
    dl1rs = np.append(dl1rs, array)

# %%
plt.hist(dl1rs, bins = 300, color = 'blue')
plt.xlabel('jet DL1R')
plt.ylabel('Counts');

# %%
datacut = data.drop(data.columns[np.arange(0, 9)], axis=1)
datacut = datacut.drop(datacut.columns[np.arange(155, 158)], axis=1)
datacut
# Out:
#          jet1_pt  jet1_eta  jet1_phi     jet1_E  jet1_DL1R   jet2_pt  \
# 0       105040.0 -2.565850  3.109660   687515.0   0.821957   27327.0
# 1        55669.8  0.573075 -2.825650    65437.1  -1.149950   41091.6
# 2       134042.0 -2.222750 -2.085920   626120.0  -4.197140  102334.0
# 3        62210.8  0.332088  2.044540    66675.6  -2.511790   45214.9
# 4        94718.6  2.459890 -2.316080   558428.0  -2.071310   46526.5
# ...          ...       ...       ...        ...        ...       ...
# 474330   37710.9  4.099960 -0.792859  1138010.0  -1.516010   30938.7
# 474331   82349.1  1.529610 -2.836830   199412.0   1.913330   41355.1
# 474332  137793.0 -2.089250 -1.475760   565412.0  -2.875450   55339.2
# 474333   83623.9 -0.338183 -0.676080    89076.8  -3.154590   37328.9
# 474334   85825.5  2.041190 -1.105750   336367.0  -2.383330   43264.1
#
#         jet2_eta  jet2_phi     jet2_E  jet2_DL1R  ...  jet30_pt  jet30_eta  \
# 0      -3.584420  -2.37550   492724.0  -2.374580  ...       NaN        NaN
# 1      -2.524660   2.94957   258305.0  -2.723700  ...       NaN        NaN
# 2      -0.759561   3.10236   133688.0  -1.100980  ...       NaN        NaN
# 3       0.522917  -2.24057    51662.8  -3.797110  ...       NaN        NaN
# 4       1.055390  -3.09643    75529.9  -2.725430  ...       NaN        NaN
# ...          ...       ...        ...        ...  ...       ...        ...
# 474330  3.794450   2.95596   688036.0  -2.107740  ...       NaN        NaN
# 474331  0.661173  -2.25343    51186.3  -0.176991  ...       NaN        NaN
# 474332  3.631040  -1.99520  1045320.0  -1.983300  ...       NaN        NaN
# 474333 -0.447093   1.51664    41452.9  -2.525560  ...       NaN        NaN
# 474334 -1.608210   2.43643   112633.0  -2.540510  ...       NaN        NaN
#
#         jet30_phi  jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  \
# 0             NaN      NaN         NaN       NaN        NaN        NaN
# 1             NaN      NaN         NaN       NaN        NaN        NaN
# 2             NaN      NaN         NaN       NaN        NaN        NaN
# 3             NaN      NaN         NaN       NaN        NaN        NaN
# 4             NaN      NaN         NaN       NaN        NaN        NaN
# ...           ...      ...         ...       ...        ...        ...
# 474330        NaN      NaN         NaN       NaN        NaN        NaN
# 474331        NaN      NaN         NaN       NaN        NaN        NaN
# 474332        NaN      NaN         NaN       NaN        NaN        NaN
# 474333        NaN      NaN         NaN       NaN        NaN        NaN
# 474334        NaN      NaN         NaN       NaN        NaN        NaN
#
#         jet31_E  jet31_DL1R
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ...         ...         ...
# 474330      NaN         NaN
# 474331      NaN         NaN
# 474332      NaN         NaN
# 474333      NaN         NaN
# 474334      NaN         NaN
#
# [474335 rows x 155 columns]

# %%
d_array = datacut.values
d_array_f = np.nan_to_num(d_array, nan = -9000)
data_array_r = d_array_f.reshape(474335, 31, 5)
for i in range(474335):
    data_array_r[i] = data_array_r[i, :, :][data_array_r[i, :, 4].argsort()[::-1]]

# %%
columns_sorted = []

for i in range (1,32):
    columns_sorted.append( 'jet' + str(i) + '_pt' )
    columns_sorted.append( 'jet' + str(i) + '_eta' )
    columns_sorted.append( 'jet' + str(i) + '_phi' )
    columns_sorted.append( 'jet' + str(i) + '_E' )
    columns_sorted.append( 'jet' + str(i) + '_DL1R' )

# %%
data_sorted_DL1R = pd.DataFrame(data_array_r.reshape(474335, 155), columns = columns_sorted)
data_sorted_DL1R
# Out:
#          jet1_pt  jet1_eta  jet1_phi     jet1_E  jet1_DL1R  jet2_pt  jet2_eta  \
# 0       105040.0 -2.565850  3.109660   687515.0   0.821957  27327.0 -3.584420
# 1        32800.0 -1.639270  3.035200    87803.2   1.125830  55669.8  0.573075
# 2       102334.0 -0.759561  3.102360   133688.0  -1.100980  30186.0 -2.271690
# 3        42985.0 -1.100870 -2.282770    72029.4  -0.349836  62210.8  0.332088
# 4        94718.6  2.459890 -2.316080   558428.0  -2.071310  36219.5 -0.665886
# ...          ...       ...       ...        ...        ...      ...       ...
# 474330   37710.9  4.099960 -0.792859  1138010.0  -1.516010  30938.7  3.794450
# 474331   82349.1  1.529610 -2.836830   199412.0   1.913330  41355.1  0.661173
# 474332   55339.2  3.631040 -1.995200  1045320.0  -1.983300  29511.4 -1.681020
# 474333   37328.9 -0.447093  1.516640    41452.9  -2.525560  83623.9 -0.338183
# 474334   25349.3  2.854050  1.869370   220735.0  -2.015550  85825.5  2.041190
#
#         jet2_phi    jet2_E  jet2_DL1R  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0       -2.37550  492724.0  -2.374580  ...   -9000.0    -9000.0    -9000.0
# 1       -2.82565   65437.1  -1.149950  ...   -9000.0    -9000.0    -9000.0
# 2       -0.66920  147985.0  -1.921490  ...   -9000.0    -9000.0    -9000.0
# 3        2.04454   66675.6  -2.511790  ...   -9000.0    -9000.0    -9000.0
# 4       -1.68770   44776.4  -2.367930  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 474330   2.95596  688036.0  -2.107740  ...   -9000.0    -9000.0    -9000.0
# 474331  -2.25343   51186.3  -0.176991  ...   -9000.0    -9000.0    -9000.0
# 474332  -2.52191   82152.8  -2.550020  ...   -9000.0    -9000.0    -9000.0
# 474333  -0.67608   89076.8  -3.154590  ...   -9000.0    -9000.0    -9000.0
# 474334  -1.10575  336367.0  -2.383330  ...   -9000.0    -9000.0    -9000.0
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 474330  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474331  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474332  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474333  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474334  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet31_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 474330     -9000.0
# 474331     -9000.0
# 474332     -9000.0
# 474333     -9000.0
# 474334     -9000.0
#
# [474335 rows x 155 columns]

# %%
##### sort by DL1R

# %%
ggf_sorted = photons.join(data_sorted_DL1R)
ggf_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0       114963.0 -2.034150  0.355817  447008.0  42368.2 -2.150490 -1.904770
# 1       117983.0  0.551337  0.540234  136373.0  76804.9  0.196550 -0.815340
# 2       169230.0  0.505756  0.370448  191339.0  79217.6  0.705594  1.491940
# 3        71142.0  0.791507 -0.077236   94614.7  38983.1 -1.129860  0.995488
# 4       172186.0  0.244196  0.668175  177345.0  22768.6  0.106687 -2.687370
# ...          ...       ...       ...       ...      ...       ...       ...
# 474330   61420.3 -0.564030 -1.835940   71451.9  60212.7 -1.136410  1.539250
# 474331  113310.0  0.303105  0.416738  118555.0  29344.7  2.028880  1.519460
# 474332  173313.0 -1.242390  1.128600  325185.0  77625.7 -0.905126  2.191610
# 474333   55301.3  0.485680  2.158840   61952.8  47840.8 -0.817640 -1.377170
# 474334   61309.6  0.390736 -2.801180   66049.7  58066.8  0.894233  0.323046
#
#             y2_E  Njets   jet1_pt  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0       184418.0      3  105040.0  ...   -9000.0    -9000.0    -9000.0
# 1        78293.2      3   32800.0  ...   -9000.0    -9000.0    -9000.0
# 2        99769.2      3  102334.0  ...   -9000.0    -9000.0    -9000.0
# 3        66628.1      3   42985.0  ...   -9000.0    -9000.0    -9000.0
# 4        22898.3      3   94718.6  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 474330  103461.0      3   37710.9  ...   -9000.0    -9000.0    -9000.0
# 474331  113521.0      4   82349.1  ...   -9000.0    -9000.0    -9000.0
# 474332  111654.0      3   55339.2  ...   -9000.0    -9000.0    -9000.0
# 474333   64743.4      3   37328.9  ...   -9000.0    -9000.0    -9000.0
# 474334   82872.4      5   25349.3  ...   -9000.0    -9000.0    -9000.0
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 474330  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474331  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474332  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474333  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474334  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet31_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 474330     -9000.0
# 474331     -9000.0
# 474332     -9000.0
# 474333     -9000.0
# 474334     -9000.0
#
# [474335 rows x 164 columns]

# %%
ggf_sorted.to_csv('ggf_SDL1R.csv', index = True)

# %%
#######

# %%
b_jet_data = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(5, 155)], axis=1)
b_jet_data
# Out:
#          jet1_pt  jet1_eta  jet1_phi     jet1_E  jet1_DL1R
# 0       105040.0 -2.565850  3.109660   687515.0   0.821957
# 1        32800.0 -1.639270  3.035200    87803.2   1.125830
# 2       102334.0 -0.759561  3.102360   133688.0  -1.100980
# 3        42985.0 -1.100870 -2.282770    72029.4  -0.349836
# 4        94718.6  2.459890 -2.316080   558428.0  -2.071310
# ...          ...       ...       ...        ...        ...
# 474330   37710.9  4.099960 -0.792859  1138010.0  -1.516010
# 474331   82349.1  1.529610 -2.836830   199412.0   1.913330
# 474332   55339.2  3.631040 -1.995200  1045320.0  -1.983300
# 474333   37328.9 -0.447093  1.516640    41452.9  -2.525560
# 474334   25349.3  2.854050  1.869370   220735.0  -2.015550
#
# [474335 rows x 5 columns]

# %%
other_jets = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(0, 5)], axis=1)
other_jets
# Out:
#         jet2_pt  jet2_eta  jet2_phi    jet2_E  jet2_DL1R   jet3_pt  jet3_eta  \
# 0       27327.0 -3.584420  -2.37550  492724.0  -2.374580   26664.4 -0.636771
# 1       55669.8  0.573075  -2.82565   65437.1  -1.149950   41091.6 -2.524660
# 2       30186.0 -2.271690  -0.66920  147985.0  -1.921490  134042.0 -2.222750
# 3       62210.8  0.332088   2.04454   66675.6  -2.511790   45214.9  0.522917
# 4       36219.5 -0.665886  -1.68770   44776.4  -2.367930   46526.5  1.055390
# ...         ...       ...       ...       ...        ...       ...       ...
# 474330  30938.7  3.794450   2.95596  688036.0  -2.107740   29627.4  2.918240
# 474331  41355.1  0.661173  -2.25343   51186.3  -0.176991   27124.1  0.924831
# 474332  29511.4 -1.681020  -2.52191   82152.8  -2.550020  137793.0 -2.089250
# 474333  83623.9 -0.338183  -0.67608   89076.8  -3.154590   34554.1 -0.660473
# 474334  85825.5  2.041190  -1.10575  336367.0  -2.383330   40422.3  1.533240
#
#         jet3_phi    jet3_E  jet3_DL1R  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0      -0.878972   32582.8   -2.48467  ...   -9000.0    -9000.0    -9000.0
# 1       2.949570  258305.0   -2.72370  ...   -9000.0    -9000.0    -9000.0
# 2      -2.085920  626120.0   -4.19714  ...   -9000.0    -9000.0    -9000.0
# 3      -2.240570   51662.8   -3.79711  ...   -9000.0    -9000.0    -9000.0
# 4      -3.096430   75529.9   -2.72543  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 474330  0.049054  275051.0   -2.70075  ...   -9000.0    -9000.0    -9000.0
# 474331  2.968410   40092.9   -1.26921  ...   -9000.0    -9000.0    -9000.0
# 474332 -1.475760  565412.0   -2.87545  ...   -9000.0    -9000.0    -9000.0
# 474333  3.034170   42770.1   -3.70613  ...   -9000.0    -9000.0    -9000.0
# 474334 -0.211746   98273.7   -2.44477  ...   -9000.0    -9000.0    -9000.0
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 474330  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474331  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474332  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474333  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474334  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet31_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 474330     -9000.0
# 474331     -9000.0
# 474332     -9000.0
# 474333     -9000.0
# 474334     -9000.0
#
# [474335 rows x 150 columns]

# %%
oth_jets_array = other_jets.values.reshape(474335, 30, 5)

# %%
for i in range(474335):
    oth_jets_array[i] = oth_jets_array[i, :, :][oth_jets_array[i, :, 0].argsort()[::-1]]

# %%
oth_jets_sorted = pd.DataFrame(oth_jets_array.reshape(474335, 150), columns = columns_sorted[5:])
oth_jets_sorted
# Out:
#          jet2_pt  jet2_eta  jet2_phi    jet2_E  jet2_DL1R  jet3_pt  jet3_eta  \
# 0        27327.0 -3.584420  -2.37550  492724.0  -2.374580  26664.4 -0.636771
# 1        55669.8  0.573075  -2.82565   65437.1  -1.149950  41091.6 -2.524660
# 2       134042.0 -2.222750  -2.08592  626120.0  -4.197140  30186.0 -2.271690
# 3        62210.8  0.332088   2.04454   66675.6  -2.511790  45214.9  0.522917
# 4        46526.5  1.055390  -3.09643   75529.9  -2.725430  36219.5 -0.665886
# ...          ...       ...       ...       ...        ...      ...       ...
# 474330   30938.7  3.794450   2.95596  688036.0  -2.107740  29627.4  2.918240
# 474331   41355.1  0.661173  -2.25343   51186.3  -0.176991  31177.1 -2.895010
# 474332  137793.0 -2.089250  -1.47576  565412.0  -2.875450  29511.4 -1.681020
# 474333   83623.9 -0.338183  -0.67608   89076.8  -3.154590  34554.1 -0.660473
# 474334   85825.5  2.041190  -1.10575  336367.0  -2.383330  43264.1 -1.608210
#
#         jet3_phi    jet3_E  jet3_DL1R  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0      -0.878972   32582.8   -2.48467  ...   -9000.0    -9000.0    -9000.0
# 1       2.949570  258305.0   -2.72370  ...   -9000.0    -9000.0    -9000.0
# 2      -0.669200  147985.0   -1.92149  ...   -9000.0    -9000.0    -9000.0
# 3      -2.240570   51662.8   -3.79711  ...   -9000.0    -9000.0    -9000.0
# 4      -1.687700   44776.4   -2.36793  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 474330  0.049054  275051.0   -2.70075  ...   -9000.0    -9000.0    -9000.0
# 474331 -2.577560  282817.0   -1.28610  ...   -9000.0    -9000.0    -9000.0
# 474332 -2.521910   82152.8   -2.55002  ...   -9000.0    -9000.0    -9000.0
# 474333  3.034170   42770.1   -3.70613  ...   -9000.0    -9000.0    -9000.0
# 474334  2.436430  112633.0   -2.54051  ...   -9000.0    -9000.0    -9000.0
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 474330  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474331  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474332  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474333  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474334  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet31_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 474330     -9000.0
# 474331     -9000.0
# 474332     -9000.0
# 474333     -9000.0
# 474334     -9000.0
#
# [474335 rows x 150 columns]

# %%
jets3 = b_jet_data.join(oth_jets_sorted)
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi     jet1_E  jet1_DL1R   jet2_pt  \
# 0       105040.0 -2.565850  3.109660   687515.0   0.821957   27327.0
# 1        32800.0 -1.639270  3.035200    87803.2   1.125830   55669.8
# 2       102334.0 -0.759561  3.102360   133688.0  -1.100980  134042.0
# 3        42985.0 -1.100870 -2.282770    72029.4  -0.349836   62210.8
# 4        94718.6  2.459890 -2.316080   558428.0  -2.071310   46526.5
# ...          ...       ...       ...        ...        ...       ...
# 474330   37710.9  4.099960 -0.792859  1138010.0  -1.516010   30938.7
# 474331   82349.1  1.529610 -2.836830   199412.0   1.913330   41355.1
# 474332   55339.2  3.631040 -1.995200  1045320.0  -1.983300  137793.0
# 474333   37328.9 -0.447093  1.516640    41452.9  -2.525560   83623.9
# 474334   25349.3  2.854050  1.869370   220735.0  -2.015550   85825.5
#
#         jet2_eta  jet2_phi    jet2_E  jet2_DL1R  ...  jet30_pt  jet30_eta  \
# 0      -3.584420  -2.37550  492724.0  -2.374580  ...   -9000.0    -9000.0
# 1       0.573075  -2.82565   65437.1  -1.149950  ...   -9000.0    -9000.0
# 2      -2.222750  -2.08592  626120.0  -4.197140  ...   -9000.0    -9000.0
# 3       0.332088   2.04454   66675.6  -2.511790  ...   -9000.0    -9000.0
# 4       1.055390  -3.09643   75529.9  -2.725430  ...   -9000.0    -9000.0
# ...          ...       ...       ...        ...  ...       ...        ...
# 474330  3.794450   2.95596  688036.0  -2.107740  ...   -9000.0    -9000.0
# 474331  0.661173  -2.25343   51186.3  -0.176991  ...   -9000.0    -9000.0
# 474332 -2.089250  -1.47576  565412.0  -2.875450  ...   -9000.0    -9000.0
# 474333 -0.338183  -0.67608   89076.8  -3.154590  ...   -9000.0    -9000.0
# 474334  2.041190  -1.10575  336367.0  -2.383330  ...   -9000.0    -9000.0
#
#         jet30_phi  jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  \
# 0         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 1         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 2         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 3         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 4         -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# ...           ...      ...         ...       ...        ...        ...
# 474330    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 474331    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 474332    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 474333    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
# 474334    -9000.0  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0
#
#         jet31_E  jet31_DL1R
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 474330  -9000.0     -9000.0
# 474331  -9000.0     -9000.0
# 474332  -9000.0     -9000.0
# 474333  -9000.0     -9000.0
# 474334  -9000.0     -9000.0
#
# [474335 rows x 155 columns]

# %%
ggf_sorted = photons.join(jets3)
ggf_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0       114963.0 -2.034150  0.355817  447008.0  42368.2 -2.150490 -1.904770
# 1       117983.0  0.551337  0.540234  136373.0  76804.9  0.196550 -0.815340
# 2       169230.0  0.505756  0.370448  191339.0  79217.6  0.705594  1.491940
# 3        71142.0  0.791507 -0.077236   94614.7  38983.1 -1.129860  0.995488
# 4       172186.0  0.244196  0.668175  177345.0  22768.6  0.106687 -2.687370
# ...          ...       ...       ...       ...      ...       ...       ...
# 474330   61420.3 -0.564030 -1.835940   71451.9  60212.7 -1.136410  1.539250
# 474331  113310.0  0.303105  0.416738  118555.0  29344.7  2.028880  1.519460
# 474332  173313.0 -1.242390  1.128600  325185.0  77625.7 -0.905126  2.191610
# 474333   55301.3  0.485680  2.158840   61952.8  47840.8 -0.817640 -1.377170
# 474334   61309.6  0.390736 -2.801180   66049.7  58066.8  0.894233  0.323046
#
#             y2_E  Njets   jet1_pt  ...  jet30_pt  jet30_eta  jet30_phi  \
# 0       184418.0      3  105040.0  ...   -9000.0    -9000.0    -9000.0
# 1        78293.2      3   32800.0  ...   -9000.0    -9000.0    -9000.0
# 2        99769.2      3  102334.0  ...   -9000.0    -9000.0    -9000.0
# 3        66628.1      3   42985.0  ...   -9000.0    -9000.0    -9000.0
# 4        22898.3      3   94718.6  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 474330  103461.0      3   37710.9  ...   -9000.0    -9000.0    -9000.0
# 474331  113521.0      4   82349.1  ...   -9000.0    -9000.0    -9000.0
# 474332  111654.0      3   55339.2  ...   -9000.0    -9000.0    -9000.0
# 474333   64743.4      3   37328.9  ...   -9000.0    -9000.0    -9000.0
# 474334   82872.4      5   25349.3  ...   -9000.0    -9000.0    -9000.0
#
#         jet30_E  jet30_DL1R  jet31_pt  jet31_eta  jet31_phi  jet31_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 474330  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474331  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474332  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474333  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 474334  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet31_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 474330     -9000.0
# 474331     -9000.0
# 474332     -9000.0
# 474333     -9000.0
# 474334     -9000.0
#
# [474335 rows x 164 columns]

# %%
ggf_sorted.to_csv('ggf_sorted.csv', index = True)

# %%
jets3 = jets3.loc[jets3['jet1_DL1R'] > 0]

# %%
def fomjets(x, num):
    
    string = 'jet' + str(num) + '_'
    E = x[string + 'E']
    px = abs(x[string + 'pt']) * np.cos(x[string + 'phi'])
    py = abs(x[string + 'pt']) * np.sin(x[string + 'phi'])
    pz = x[string + 'pt']/(np.tan(2*np.arctan(np.exp(-x[string + 'eta']))))

    return np.array([E, px, py, pz])

# %%
for i in range (1,4):
    
    jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# Out:
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_15332\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_15332\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_15332\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)

# %%
jets3 = jets3.assign(quark_fom = jets3.jet1_fom + jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3 = jets3.assign(wboson_fom = jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       105040.0 -2.565850  3.109660  687515.0   0.821957   27327.0 -3.584420
# 1        32800.0 -1.639270  3.035200   87803.2   1.125830   55669.8  0.573075
# 5        99121.8  1.306090 -0.043219  197223.0   5.427240   58422.5 -0.182141
# 6        28303.0  0.476921 -2.529890   31910.5   1.093680   45596.9 -2.124520
# 7        26278.0  1.223100 -0.334624   48849.9   0.101077   58233.7 -0.687347
# ...          ...       ...       ...       ...        ...       ...       ...
# 474286  133678.0  1.409500  0.037030  290669.0   0.479513  136459.0  1.659110
# 474297   69514.2  1.300020 -3.123010  137593.0   0.280304  129421.0 -3.533290
# 474314   97454.4  0.799482 -1.770110  130980.0  10.002400   77889.0 -2.030950
# 474328   53664.5 -0.566255  2.951250   62675.6   1.423190  107333.0  1.754470
# 474331   82349.1  1.529610 -2.836830  199412.0   1.913330   41355.1  0.661173
#
#         jet2_phi     jet2_E  jet2_DL1R  ...  jet31_pt  jet31_eta  jet31_phi  \
# 0      -2.375500   492724.0  -2.374580  ...   -9000.0    -9000.0    -9000.0
# 1      -2.825650    65437.1  -1.149950  ...   -9000.0    -9000.0    -9000.0
# 5       1.484300    60767.3  -3.744430  ...   -9000.0    -9000.0    -9000.0
# 6       2.299280   193569.0  -4.414970  ...   -9000.0    -9000.0    -9000.0
# 7       2.770160    73460.3  -1.882880  ...   -9000.0    -9000.0    -9000.0
# ...          ...        ...        ...  ...       ...        ...        ...
# 474286  2.920760   371680.0  -4.793690  ...   -9000.0    -9000.0    -9000.0
# 474297  0.172509  2217410.0  -2.080410  ...   -9000.0    -9000.0    -9000.0
# 474314  1.546760   302059.0   3.437680  ...   -9000.0    -9000.0    -9000.0
# 474328 -2.750210   319722.0  -3.727490  ...   -9000.0    -9000.0    -9000.0
# 474331 -2.253430    51186.3  -0.176991  ...   -9000.0    -9000.0    -9000.0
#
#         jet31_E  jet31_DL1R  \
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 5       -9000.0     -9000.0
# 6       -9000.0     -9000.0
# 7       -9000.0     -9000.0
# ...         ...         ...
# 474286  -9000.0     -9000.0
# 474297  -9000.0     -9000.0
# 474314  -9000.0     -9000.0
# 474328  -9000.0     -9000.0
# 474331  -9000.0     -9000.0
#
#                                                  jet1_fom  \
# 0       [687515.0, -104986.4502025361, 3353.6359179864...
# 1       [87803.2, -32614.53693672254, 3483.09925255670...
# 5       [197223.0, 99029.24092604412, -4282.6016452044...
# 6       [31910.5, -23170.8576357822, -16253.3432075469...
# 7       [48849.9, 24820.460775159318, -8630.0643629568...
# ...                                                   ...
# 474286  [290669.0, 133586.3604283943, 4948.93842102743...
# 474297  [137593.0, -69502.19819688454, -1291.683955532...
# 474314  [130980.0, -19295.643568410393, -95525.0659180...
# 474328  [62675.6, -52695.290381440216, 10153.074995571...
# 474331  [199412.0, -78554.30517836011, -24710.22882846...
#
#                                                  jet2_fom  \
# 0       [492724.0, -19692.525494155016, -18946.4869741...
# 1       [65437.1, -52914.362396994475, -17297.30858138...
# 5       [60767.3, 5047.03282897, 58204.088910258695, -...
# 6       [193569.0, -30355.631913169997, 34023.71086113...
# 7       [73460.3, -54262.64612580266, 21135.9658193306...
# ...                                                   ...
# 474286  [371680.0, -133145.14795580236, 29890.27027023...
# 474297  [2217410.0, 127500.02825663454, 22215.71595869...
# 474314  [302059.0, 1871.9851905613418, 77866.501092872...
# 474328  [319722.0, -99216.74763019994, -40943.98464591...
# 474331  [51186.3, -26088.398074822584, -32088.00059055...
#
#                                                  jet3_fom  \
# 0       [32582.8, 17010.370714538858, -20533.813954401...
# 1       [258305.0, -40336.34586378823, 7842.1166094909...
# 5       [709131.0, -19766.85509657962, -37132.00968101...
# 6       [186514.0, 25583.165092032406, 4498.7391971323...
# 7       [101292.0, -45970.70238502028, 10981.332844326...
# ...                                                   ...
# 474286  [91303.4, 76214.72848822593, -25535.5957617206...
# 474297  [406596.0, -73866.07895567646, -36575.02508274...
# 474314  [38363.5, -33075.008429912035, 14561.917972961...
# 474328  [254973.0, 35193.003535891214, 76938.237367142...
# 474331  [282817.0, -26347.958567073085, -16667.2326364...
#
#                                                 quark_fom  \
# 0       [1212821.8, -107668.60498215225, -36126.665010...
# 1       [411545.3, -125865.24519750524, -5972.09271933...
# 5       [967121.3, 84309.4186584345, 16789.47758404146...
# 6       [411993.5, -27943.32445691979, 22269.106850720...
# 7       [223602.2, -75412.88773566362, 23487.234300700...
# ...                                                   ...
# 474286  [753652.4, 76655.94096081788, 9303.61292953852...
# 474297  [2761599.0, -15868.24889592646, -15650.9930795...
# 474314  [471402.5, -50498.66680776108, -3096.646852180...
# 474328  [637370.6, -116719.03447574895, 46147.32771679...
# 474331  [533415.3, -130990.66182025579, -73465.4620554...
#
#                                                wboson_fom
# 0       [525306.8, -2682.1547796161576, -39480.3009285...
# 1       [323742.1, -93250.7082607827, -9455.1919718906...
# 5       [769898.3, -14719.82226760962, 21072.079229245...
# 6       [380083.0, -4772.46682113759, 38522.4500582676...
# 7       [174752.3, -100233.34851082295, 32117.29866365...
# ...                                                   ...
# 474286  [462983.4, -56930.41946757643, 4354.6745085111...
# 474297  [2624006.0, 53633.94930095808, -14359.30912405...
# 474314  [340422.5, -31203.023239350692, 92428.41906583...
# 474328  [574695.0, -64023.74409430873, 35994.252721223...
# 474331  [334003.3, -52436.35664189567, -48755.23322701...
#
# [97870 rows x 160 columns]

# %%
quark_m = []

for row in jets3.quark_fom:
    quark_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(quark_m, bins = 1000, color = 'blue')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('Quark Mass');

# %%
wboson_m = []

for row in jets3.wboson_fom:
    wboson_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(wboson_m, bins = 1000, color = 'green')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('W boson Mass');
