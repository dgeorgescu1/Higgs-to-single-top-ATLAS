# %% [markdown]
# # Open data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from iminuit import Minuit
from scipy import integrate

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9, 6) # inches
plt.rcParams['font.size'] = 9

# %%
columns = ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E']
for i in range (1,19):
    columns.append( 'jet' + str(i) + '_pt' )
    columns.append( 'jet' + str(i) + '_eta' )
    columns.append( 'jet' + str(i) + '_phi' )
    columns.append( 'jet' + str(i) + '_E' )
    columns.append( 'jet' + str(i) + '_DL1R' )
    
print (columns)
# Out:
# ['y1_pt', 'y1_eta', 'y1_phi', 'y1_E', 'y2_pt', 'y2_eta', 'y2_phi', 'y2_E', 'jet1_pt', 'jet1_eta', 'jet1_phi', 'jet1_E', 'jet1_DL1R', 'jet2_pt', 'jet2_eta', 'jet2_phi', 'jet2_E', 'jet2_DL1R', 'jet3_pt', 'jet3_eta', 'jet3_phi', 'jet3_E', 'jet3_DL1R', 'jet4_pt', 'jet4_eta', 'jet4_phi', 'jet4_E', 'jet4_DL1R', 'jet5_pt', 'jet5_eta', 'jet5_phi', 'jet5_E', 'jet5_DL1R', 'jet6_pt', 'jet6_eta', 'jet6_phi', 'jet6_E', 'jet6_DL1R', 'jet7_pt', 'jet7_eta', 'jet7_phi', 'jet7_E', 'jet7_DL1R', 'jet8_pt', 'jet8_eta', 'jet8_phi', 'jet8_E', 'jet8_DL1R', 'jet9_pt', 'jet9_eta', 'jet9_phi', 'jet9_E', 'jet9_DL1R', 'jet10_pt', 'jet10_eta', 'jet10_phi', 'jet10_E', 'jet10_DL1R', 'jet11_pt', 'jet11_eta', 'jet11_phi', 'jet11_E', 'jet11_DL1R', 'jet12_pt', 'jet12_eta', 'jet12_phi', 'jet12_E', 'jet12_DL1R', 'jet13_pt', 'jet13_eta', 'jet13_phi', 'jet13_E', 'jet13_DL1R', 'jet14_pt', 'jet14_eta', 'jet14_phi', 'jet14_E', 'jet14_DL1R', 'jet15_pt', 'jet15_eta', 'jet15_phi', 'jet15_E', 'jet15_DL1R', 'jet16_pt', 'jet16_eta', 'jet16_phi', 'jet16_E', 'jet16_DL1R', 'jet17_pt', 'jet17_eta', 'jet17_phi', 'jet17_E', 'jet17_DL1R', 'jet18_pt', 'jet18_eta', 'jet18_phi', 'jet18_E', 'jet18_DL1R']

# %%
data = pd.read_csv('ttH.csv', header = None, names = columns)

# %%
data
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E   jet1_pt  jet1_eta  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0       266972.0  131378.0 -0.329794  ...       NaN        NaN        NaN
# 1        88654.9  134531.0 -0.585078  ...       NaN        NaN        NaN
# 2        41536.6  330142.0  0.450489  ...       NaN        NaN        NaN
# 3        67142.7  106924.0  0.095347  ...       NaN        NaN        NaN
# 4       221566.0   48883.5  2.484270  ...       NaN        NaN        NaN
# ...          ...       ...       ...  ...       ...        ...        ...
# 447829  157809.0  251206.0 -1.048900  ...       NaN        NaN        NaN
# 447830  103316.0  102291.0  1.928240  ...       NaN        NaN        NaN
# 447831   60634.2  149037.0  0.535809  ...       NaN        NaN        NaN
# 447832  238983.0  115269.0 -0.630386  ...       NaN        NaN        NaN
# 447833   75197.8   89664.7 -1.346250  ...       NaN        NaN        NaN
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0           NaN         NaN       NaN        NaN        NaN      NaN
# 1           NaN         NaN       NaN        NaN        NaN      NaN
# 2           NaN         NaN       NaN        NaN        NaN      NaN
# 3           NaN         NaN       NaN        NaN        NaN      NaN
# 4           NaN         NaN       NaN        NaN        NaN      NaN
# ...         ...         ...       ...        ...        ...      ...
# 447829      NaN         NaN       NaN        NaN        NaN      NaN
# 447830      NaN         NaN       NaN        NaN        NaN      NaN
# 447831      NaN         NaN       NaN        NaN        NaN      NaN
# 447832      NaN         NaN       NaN        NaN        NaN      NaN
# 447833      NaN         NaN       NaN        NaN        NaN      NaN
#
#         jet18_DL1R
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 447829         NaN
# 447830         NaN
# 447831         NaN
# 447832         NaN
# 447833         NaN
#
# [447834 rows x 98 columns]

# %% [markdown]
# ## Add in Njets

# %%
data_array = data.values
data_array
# Out:
# array([[ 6.98640e+04, -1.70762e+00, -7.76301e-02, ...,          nan,
#                  nan,          nan],
#        [ 1.12940e+05,  8.91460e-01, -7.95433e-01, ...,          nan,
#                  nan,          nan],
#        [ 1.60426e+05, -5.65636e-01, -2.49423e+00, ...,          nan,
#                  nan,          nan],
#        ...,
#        [ 1.15807e+05,  4.35172e-01,  1.51563e+00, ...,          nan,
#                  nan,          nan],
#        [ 1.10617e+05, -1.10820e+00,  6.95576e-01, ...,          nan,
#                  nan,          nan],
#        [ 6.97800e+04, -1.11994e+00, -1.19159e+00, ...,          nan,
#                  nan,          nan]])

# %%
Njets = ((np.count_nonzero(~np.isnan(data_array), axis = 1) - 8) / 5).astype(int)

# %%
data_array_wjets = np.append(data_array, Njets.reshape(447834, 1), axis = 1)

# %% [markdown]
# ## Dataframe again

# %%
columns.append('Njets')

# %%
data = pd.DataFrame(data_array_wjets, columns = columns)

# %%
data
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E   jet1_pt  jet1_eta  ...  jet17_eta  jet17_phi  jet17_E  \
# 0       266972.0  131378.0 -0.329794  ...        NaN        NaN      NaN
# 1        88654.9  134531.0 -0.585078  ...        NaN        NaN      NaN
# 2        41536.6  330142.0  0.450489  ...        NaN        NaN      NaN
# 3        67142.7  106924.0  0.095347  ...        NaN        NaN      NaN
# 4       221566.0   48883.5  2.484270  ...        NaN        NaN      NaN
# ...          ...       ...       ...  ...        ...        ...      ...
# 447829  157809.0  251206.0 -1.048900  ...        NaN        NaN      NaN
# 447830  103316.0  102291.0  1.928240  ...        NaN        NaN      NaN
# 447831   60634.2  149037.0  0.535809  ...        NaN        NaN      NaN
# 447832  238983.0  115269.0 -0.630386  ...        NaN        NaN      NaN
# 447833   75197.8   89664.7 -1.346250  ...        NaN        NaN      NaN
#
#         jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  jet18_DL1R  Njets
# 0              NaN       NaN        NaN        NaN      NaN         NaN    4.0
# 1              NaN       NaN        NaN        NaN      NaN         NaN    4.0
# 2              NaN       NaN        NaN        NaN      NaN         NaN    6.0
# 3              NaN       NaN        NaN        NaN      NaN         NaN    4.0
# 4              NaN       NaN        NaN        NaN      NaN         NaN    4.0
# ...            ...       ...        ...        ...      ...         ...    ...
# 447829         NaN       NaN        NaN        NaN      NaN         NaN    7.0
# 447830         NaN       NaN        NaN        NaN      NaN         NaN    5.0
# 447831         NaN       NaN        NaN        NaN      NaN         NaN    5.0
# 447832         NaN       NaN        NaN        NaN      NaN         NaN    4.0
# 447833         NaN       NaN        NaN        NaN      NaN         NaN    6.0
#
# [447834 rows x 99 columns]

# %% [markdown]
# ## bit with photon info. and Njets

# %%
photons = data.drop(data.columns[np.arange(8, 98)], axis=1)
photons
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E  Njets
# 0       266972.0    4.0
# 1        88654.9    4.0
# 2        41536.6    6.0
# 3        67142.7    4.0
# 4       221566.0    4.0
# ...          ...    ...
# 447829  157809.0    7.0
# 447830  103316.0    5.0
# 447831   60634.2    5.0
# 447832  238983.0    4.0
# 447833   75197.8    6.0
#
# [447834 rows x 9 columns]

# %% [markdown]
# # Plot photon bck (ttH) variables

# %%
fig, axs = plt.subplots(2, 2)

axs[0, 0].hist(data['y1_pt'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_pt')
axs[0, 0].hist(data['y2_pt'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_pt');
axs[0,0].set_xlabel('Momentum (MeV)')
axs[0,0].set_ylabel('Counts')
axs[0,0].set_xlim(0, 0.35e6)
axs[0,0].legend()

axs[0, 1].hist(data['y1_eta'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_eta')
axs[0, 1].hist(data['y2_eta'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_eta');
axs[0,1].set_xlabel('Eta (pseudorapidity)')
axs[0,1].set_ylabel('Counts')
axs[0,1].legend()

axs[1, 0].hist(data['y1_phi'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_phi')
axs[1, 0].hist(data['y2_phi'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_phi');
axs[1,0].set_xlabel('Phi')
axs[1,0].set_ylabel('Counts')
axs[1,0].legend()

axs[1, 1].hist(data['y1_E'], bins = 300, color = 'magenta', alpha = 0.5, label = 'y1_E')
axs[1, 1].hist(data['y2_E'], bins = 300, color = 'blue', alpha = 0.5, label = 'y2_E');
axs[1,1].set_xlabel('Energy (MeV)')
axs[1,1].set_ylabel('Counts')
axs[1,1].set_xlim(0, 0.7e6)
axs[1,1].legend();

fig.tight_layout()

# %% [markdown]
# # 4 Mom

# %%
def fomy(x, num):
    
    string = 'y' + str(num) + '_'
    E = x[string + 'E']
    px = abs(x[string + 'pt']) * np.cos(x[string + 'phi'])
    py = abs(x[string + 'pt']) * np.sin(x[string + 'phi'])
    pz = x[string + 'pt']/(np.tan(2*np.arctan(np.exp(-x[string + 'eta']))))

    return np.array([E, px, py, pz])

# %%
data['y1_fom'] = data.apply(lambda x: fomy(x, 1), axis = 1).apply(lambda x: x)
data['y2_fom'] = data.apply(lambda x: fomy(x, 2), axis = 1).apply(lambda x: x)
data = data.assign(H_fom = data.y1_fom + data.y2_fom)

# %% [markdown]
# ## Mass dist.

# %%
H_mass = []

for row in data.H_fom:
    H_mass.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(H_mass, bins = 5000, color = 'gold', density = True)
plt.xlim(80, 180)
plt.xlabel('Mass GeV')
plt.ylabel('Counts');

# %%
H_array = np.array(H_mass)
vals1 = (95 < H_array)
H_array = H_array[vals1]
vals2 = (170 > H_array)
H_array = H_array[vals2]

# %%
plt.hist(H_array, bins = 500, color = 'gold')
plt.xlabel('Mass GeV')
plt.ylabel('Counts');

# %%
data.describe()['Njets'][['min', 'max']]
# Out:
# min     4.0
# max    18.0
# Name: Njets, dtype: float64

# %%
n, bins, patches = plt.hist(data['Njets'], bins = 17, color = 'blue');

# %%
pts = np.array([])

for i in range(1,19):
    string = 'jet' + str(i) + '_pt'
    array = np.array(data[string])
    pts = np.append(pts, array)

# %%
n, bins, patches = plt.hist(pts, bins = 1000, color = 'blue', alpha = 0.8)
plt.xlabel('jet pt')
plt.xlim(0, 0.4*1e6)
plt.ylabel('Counts');

# %%
dl1rs = np.array([])

for i in range(1,19):
    string = 'jet' + str(i) + '_DL1R'
    array = np.array(data[string])
    dl1rs = np.append(dl1rs, array)

# %%
plt.hist(dl1rs, bins = 300, color = 'blue')
plt.xlabel('jet DL1R')
plt.ylabel('Counts');

# %%
data
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E   jet1_pt  jet1_eta  ...  jet17_DL1R  jet18_pt  jet18_eta  \
# 0       266972.0  131378.0 -0.329794  ...         NaN       NaN        NaN
# 1        88654.9  134531.0 -0.585078  ...         NaN       NaN        NaN
# 2        41536.6  330142.0  0.450489  ...         NaN       NaN        NaN
# 3        67142.7  106924.0  0.095347  ...         NaN       NaN        NaN
# 4       221566.0   48883.5  2.484270  ...         NaN       NaN        NaN
# ...          ...       ...       ...  ...         ...       ...        ...
# 447829  157809.0  251206.0 -1.048900  ...         NaN       NaN        NaN
# 447830  103316.0  102291.0  1.928240  ...         NaN       NaN        NaN
# 447831   60634.2  149037.0  0.535809  ...         NaN       NaN        NaN
# 447832  238983.0  115269.0 -0.630386  ...         NaN       NaN        NaN
# 447833   75197.8   89664.7 -1.346250  ...         NaN       NaN        NaN
#
#         jet18_phi  jet18_E  jet18_DL1R  Njets  \
# 0             NaN      NaN         NaN    4.0
# 1             NaN      NaN         NaN    4.0
# 2             NaN      NaN         NaN    6.0
# 3             NaN      NaN         NaN    4.0
# 4             NaN      NaN         NaN    4.0
# ...           ...      ...         ...    ...
# 447829        NaN      NaN         NaN    7.0
# 447830        NaN      NaN         NaN    5.0
# 447831        NaN      NaN         NaN    5.0
# 447832        NaN      NaN         NaN    4.0
# 447833        NaN      NaN         NaN    6.0
#
#                                                    y1_fom  \
# 0       [199012.0, 69653.59036263083, -5418.1035053625...
# 1       [160869.0, 79055.24397734896, -80657.994022178...
# 2       [186781.0, -127968.14873490082, -96750.4748585...
# 3       [80835.4, -50323.98571151106, -53171.288494051...
# 4       [77271.5, 30943.0608611585, 53564.3267175332, ...
# ...                                                   ...
# 447829  [769012.0, 38517.9865337927, -460241.009921304...
# 447830  [180897.0, 23167.199595512815, -66246.91407078...
# 447831  [126946.0, 6385.406846908735, 115630.825597672...
# 447832  [185784.0, 84918.97983026833, 70886.4412535040...
# 447833  [118311.0, 25831.39042474596, -64822.740367284...
#
#                                                    y2_fom  \
# 0       [266972.0, -50427.204583397506, -12770.0195342...
# 1       [88654.9, -43828.32560251018, -64997.549431423...
# 2       [41536.6, 28158.55406739908, -29887.5526236820...
# 3       [67142.7, -4639.921603716506, 62524.6733623724...
# 4       [221566.0, 30429.53468155742, -36290.543493779...
# ...                                                   ...
# 447829  [157809.0, 57757.46104255202, -68816.919930189...
# 447830  [103316.0, -64456.77065900233, 12733.031138451...
# 447831  [60634.2, -60388.28598697854, -1049.2103291961...
# 447832  [238983.0, 82061.99595197105, -44966.622685484...
# 447833  [75197.8, 45477.11401922918, -46937.5571107192...
#
#                                                     H_fom
# 0       [465984.0, 19226.385779233322, -18188.12303957...
# 1       [249523.9, 35226.91837483878, -145655.54345360...
# 2       [228317.6, -99809.59466750175, -126638.0274822...
# 3       [147978.09999999998, -54963.90731522757, 9353....
# 4       [298837.5, 61372.59554271592, 17273.7832237538...
# ...                                                   ...
# 447829  [926821.0, 96275.44757634471, -529057.92985149...
# 447830  [284213.0, -41289.571063489515, -53513.8829323...
# 447831  [187580.2, -54002.8791400698, 114581.615268476...
# 447832  [424767.0, 166980.9757822394, 25919.8185680200...
# 447833  [193508.8, 71308.50444397514, -111760.29747800...
#
# [447834 rows x 102 columns]

# %%
datacut = data.drop(data.columns[np.arange(0, 8)], axis=1)
datacut = datacut.drop(datacut.columns[np.arange(90, 94)], axis=1)
datacut
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       131378.0 -0.329794   2.39196  139261.0   9.149100  106287.0 -2.103990
# 1       134531.0 -0.585078   1.65959  159606.0  -3.278290   88162.4 -0.683700
# 2       330142.0  0.450489  -0.08554  365073.0  -4.671140  151861.0 -0.527643
# 3       106924.0  0.095347   2.03390  108049.0  -0.120393   82384.1  1.337020
# 4        48883.5  2.484270   1.87703  295333.0  -1.575380   43564.6  1.950350
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829  251206.0 -1.048900   2.16586  404058.0   1.751460  165895.0 -0.920159
# 447830  102291.0  1.928240  -2.25985  359316.0  -1.069650   96707.3  1.031870
# 447831  149037.0  0.535809  -2.40895  171236.0   6.623750   39582.4  0.162418
# 447832  115269.0 -0.630386  -2.88193  139393.0   8.095760  108443.0 -1.546010
# 447833   89664.7 -1.346250   1.34969  184557.0   0.989877   78635.9 -0.677476
#
#         jet2_phi    jet2_E  jet2_DL1R  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0      -0.915685  442340.0  -1.374850  ...       NaN        NaN        NaN
# 1      -2.871060  109829.0  -3.218360  ...       NaN        NaN        NaN
# 2       2.337050  173726.0   1.532550  ...       NaN        NaN        NaN
# 3      -0.095856  168634.0   9.795330  ...       NaN        NaN        NaN
# 4      -2.322560  156360.0   7.904280  ...       NaN        NaN        NaN
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  0.888254  241676.0  -3.759170  ...       NaN        NaN        NaN
# 447830  1.465500  153242.0   6.783540  ...       NaN        NaN        NaN
# 447831  0.040169   40809.8  -2.831830  ...       NaN        NaN        NaN
# 447832  1.931770  266360.0   8.341880  ...       NaN        NaN        NaN
# 447833  2.410430   98542.2  -0.506297  ...       NaN        NaN        NaN
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0           NaN         NaN       NaN        NaN        NaN      NaN
# 1           NaN         NaN       NaN        NaN        NaN      NaN
# 2           NaN         NaN       NaN        NaN        NaN      NaN
# 3           NaN         NaN       NaN        NaN        NaN      NaN
# 4           NaN         NaN       NaN        NaN        NaN      NaN
# ...         ...         ...       ...        ...        ...      ...
# 447829      NaN         NaN       NaN        NaN        NaN      NaN
# 447830      NaN         NaN       NaN        NaN        NaN      NaN
# 447831      NaN         NaN       NaN        NaN        NaN      NaN
# 447832      NaN         NaN       NaN        NaN        NaN      NaN
# 447833      NaN         NaN       NaN        NaN        NaN      NaN
#
#         jet18_DL1R
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 447829         NaN
# 447830         NaN
# 447831         NaN
# 447832         NaN
# 447833         NaN
#
# [447834 rows x 90 columns]

# %%
d_array = datacut.values
d_array_f = np.nan_to_num(d_array, nan = -9000)
data_array_r = d_array_f.reshape(447834, 18, 5)
for i in range(447834):
    data_array_r[i] = data_array_r[i, :, :][data_array_r[i, :, 4].argsort()[::-1]]

# %%
columns_sorted = []

for i in range (1,19):
    columns_sorted.append( 'jet' + str(i) + '_pt' )
    columns_sorted.append( 'jet' + str(i) + '_eta' )
    columns_sorted.append( 'jet' + str(i) + '_phi' )
    columns_sorted.append( 'jet' + str(i) + '_E' )
    columns_sorted.append( 'jet' + str(i) + '_DL1R' )

# %%
data_sorted_DL1R = pd.DataFrame(data_array_r.reshape(447834, 90), columns = columns_sorted)
data_sorted_DL1R
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       131378.0 -0.329794  2.391960  139261.0   9.149100  106287.0 -2.103990
# 1        75861.0  0.203770  0.437290   77672.0   9.069050   25621.5 -0.147344
# 2        58465.8 -0.522234  0.606464   67074.4  11.015300  151861.0 -0.527643
# 3        82384.1  1.337020 -0.095856  168634.0   9.795330  106924.0  0.095347
# 4        43564.6  1.950350 -2.322560  156360.0   7.904280   28994.8  0.279413
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829   27000.4  0.081570 -1.118100   27644.5   2.824140  251206.0 -1.048900
# 447830   96707.3  1.031870  1.465500  153242.0   6.783540   50477.2  0.319063
# 447831   37924.0  0.613572  0.322380   45686.8   9.146090  149037.0  0.535809
# 447832   43303.7 -2.440290  1.616870  250493.0   8.469340  108443.0 -1.546010
# 447833   89664.7 -1.346250  1.349690  184557.0   0.989877   78635.9 -0.677476
#
#         jet2_phi    jet2_E  jet2_DL1R  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0      -0.915685  442340.0  -1.374850  ...   -9000.0    -9000.0    -9000.0
# 1      -0.635806   26030.5   1.268220  ...   -9000.0    -9000.0    -9000.0
# 2       2.337050  173726.0   1.532550  ...   -9000.0    -9000.0    -9000.0
# 3       2.033900  108049.0  -0.120393  ...   -9000.0    -9000.0    -9000.0
# 4      -0.569757   30446.4   0.763840  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  2.165860  404058.0   1.751460  ...   -9000.0    -9000.0    -9000.0
# 447830  2.637690   53537.3   2.633550  ...   -9000.0    -9000.0    -9000.0
# 447831 -2.408950  171236.0   6.623750  ...   -9000.0    -9000.0    -9000.0
# 447832  1.931770  266360.0   8.341880  ...   -9000.0    -9000.0    -9000.0
# 447833  2.410430   98542.2  -0.506297  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 90 columns]

# %%
###### Sort by DL1R

# %%
ttH_sorted = photons.join(data_sorted_DL1R)
ttH_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E  Njets   jet1_pt  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0       266972.0    4.0  131378.0  ...   -9000.0    -9000.0    -9000.0
# 1        88654.9    4.0   75861.0  ...   -9000.0    -9000.0    -9000.0
# 2        41536.6    6.0   58465.8  ...   -9000.0    -9000.0    -9000.0
# 3        67142.7    4.0   82384.1  ...   -9000.0    -9000.0    -9000.0
# 4       221566.0    4.0   43564.6  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 447829  157809.0    7.0   27000.4  ...   -9000.0    -9000.0    -9000.0
# 447830  103316.0    5.0   96707.3  ...   -9000.0    -9000.0    -9000.0
# 447831   60634.2    5.0   37924.0  ...   -9000.0    -9000.0    -9000.0
# 447832  238983.0    4.0   43303.7  ...   -9000.0    -9000.0    -9000.0
# 447833   75197.8    6.0   89664.7  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 99 columns]

# %%
ttH_sorted.to_csv('ttH_SDL1R.csv', index = True)

# %%
######

# %%
b_jet_data = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(5, 90)], axis=1)
b_jet_data
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R
# 0       131378.0 -0.329794  2.391960  139261.0   9.149100
# 1        75861.0  0.203770  0.437290   77672.0   9.069050
# 2        58465.8 -0.522234  0.606464   67074.4  11.015300
# 3        82384.1  1.337020 -0.095856  168634.0   9.795330
# 4        43564.6  1.950350 -2.322560  156360.0   7.904280
# ...          ...       ...       ...       ...        ...
# 447829   27000.4  0.081570 -1.118100   27644.5   2.824140
# 447830   96707.3  1.031870  1.465500  153242.0   6.783540
# 447831   37924.0  0.613572  0.322380   45686.8   9.146090
# 447832   43303.7 -2.440290  1.616870  250493.0   8.469340
# 447833   89664.7 -1.346250  1.349690  184557.0   0.989877
#
# [447834 rows x 5 columns]

# %%
other_jets = data_sorted_DL1R.drop(data_sorted_DL1R.columns[np.arange(0, 5)], axis=1)
other_jets
# Out:
#          jet2_pt  jet2_eta  jet2_phi    jet2_E  jet2_DL1R   jet3_pt  jet3_eta  \
# 0       106287.0 -2.103990 -0.915685  442340.0  -1.374850   42473.6 -3.104610
# 1        25621.5 -0.147344 -0.635806   26030.5   1.268220   88162.4 -0.683700
# 2       151861.0 -0.527643  2.337050  173726.0   1.532550   27495.1  3.670090
# 3       106924.0  0.095347  2.033900  108049.0  -0.120393   50698.8  0.112351
# 4        28994.8  0.279413 -0.569757   30446.4   0.763840   48883.5  2.484270
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829  251206.0 -1.048900  2.165860  404058.0   1.751460   30198.8  1.460150
# 447830   50477.2  0.319063  2.637690   53537.3   2.633550  102291.0  1.928240
# 447831  149037.0  0.535809 -2.408950  171236.0   6.623750   28908.9 -0.290119
# 447832  108443.0 -1.546010  1.931770  266360.0   8.341880  115269.0 -0.630386
# 447833   78635.9 -0.677476  2.410430   98542.2  -0.506297   30417.9 -0.544264
#
#         jet3_phi    jet3_E  jet3_DL1R  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0       0.014613  474586.0  -2.501770  ...   -9000.0    -9000.0    -9000.0
# 1      -2.871060  109829.0  -3.218360  ...   -9000.0    -9000.0    -9000.0
# 2       2.926290  540016.0  -2.325270  ...   -9000.0    -9000.0    -9000.0
# 3      -2.255140   51423.9  -1.581260  ...   -9000.0    -9000.0    -9000.0
# 4       1.877030  295333.0  -1.575380  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  2.945550   68854.7  -0.958850  ...   -9000.0    -9000.0    -9000.0
# 447830 -2.259850  359316.0  -1.069650  ...   -9000.0    -9000.0    -9000.0
# 447831 -0.539817   30721.9  -0.926441  ...   -9000.0    -9000.0    -9000.0
# 447832 -2.881930  139393.0   8.095760  ...   -9000.0    -9000.0    -9000.0
# 447833  1.909780   35500.2  -2.327260  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 85 columns]

# %%
oth_jets_array = other_jets.values.reshape(447834, 17, 5)

# %%
for i in range(447834):
    oth_jets_array[i] = oth_jets_array[i, :, :][oth_jets_array[i, :, 0].argsort()[::-1]]

# %%
oth_jets_sorted = pd.DataFrame(oth_jets_array.reshape(447834, 85), columns = columns_sorted[5:])
oth_jets_sorted
# Out:
#          jet2_pt  jet2_eta  jet2_phi    jet2_E  jet2_DL1R   jet3_pt  jet3_eta  \
# 0       106287.0 -2.103990 -0.915685  442340.0  -1.374850   42473.6 -3.104610
# 1       134531.0 -0.585078  1.659590  159606.0  -3.278290   88162.4 -0.683700
# 2       330142.0  0.450489 -0.085540  365073.0  -4.671140  151861.0 -0.527643
# 3       106924.0  0.095347  2.033900  108049.0  -0.120393   50698.8  0.112351
# 4        48883.5  2.484270  1.877030  295333.0  -1.575380   33129.8  1.741720
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829  251206.0 -1.048900  2.165860  404058.0   1.751460  165895.0 -0.920159
# 447830  102291.0  1.928240 -2.259850  359316.0  -1.069650   69499.1  2.027220
# 447831  149037.0  0.535809 -2.408950  171236.0   6.623750   39582.4  0.162418
# 447832  115269.0 -0.630386 -2.881930  139393.0   8.095760  108443.0 -1.546010
# 447833   78635.9 -0.677476  2.410430   98542.2  -0.506297   77892.0 -0.226608
#
#         jet3_phi    jet3_E  jet3_DL1R  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0       0.014613  474586.0   -2.50177  ...   -9000.0    -9000.0    -9000.0
# 1      -2.871060  109829.0   -3.21836  ...   -9000.0    -9000.0    -9000.0
# 2       2.337050  173726.0    1.53255  ...   -9000.0    -9000.0    -9000.0
# 3      -2.255140   51423.9   -1.58126  ...   -9000.0    -9000.0    -9000.0
# 4       2.233400   97650.7   -2.76310  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  0.888254  241676.0   -3.75917  ...   -9000.0    -9000.0    -9000.0
# 447830  0.831701  268439.0   -3.78943  ...   -9000.0    -9000.0    -9000.0
# 447831  0.040169   40809.8   -2.83183  ...   -9000.0    -9000.0    -9000.0
# 447832  1.931770  266360.0    8.34188  ...   -9000.0    -9000.0    -9000.0
# 447833  2.750210   80954.6   -3.38079  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 85 columns]

# %%
jets3 = b_jet_data.join(oth_jets_sorted)
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       131378.0 -0.329794  2.391960  139261.0   9.149100  106287.0 -2.103990
# 1        75861.0  0.203770  0.437290   77672.0   9.069050  134531.0 -0.585078
# 2        58465.8 -0.522234  0.606464   67074.4  11.015300  330142.0  0.450489
# 3        82384.1  1.337020 -0.095856  168634.0   9.795330  106924.0  0.095347
# 4        43564.6  1.950350 -2.322560  156360.0   7.904280   48883.5  2.484270
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829   27000.4  0.081570 -1.118100   27644.5   2.824140  251206.0 -1.048900
# 447830   96707.3  1.031870  1.465500  153242.0   6.783540  102291.0  1.928240
# 447831   37924.0  0.613572  0.322380   45686.8   9.146090  149037.0  0.535809
# 447832   43303.7 -2.440290  1.616870  250493.0   8.469340  115269.0 -0.630386
# 447833   89664.7 -1.346250  1.349690  184557.0   0.989877   78635.9 -0.677476
#
#         jet2_phi    jet2_E  jet2_DL1R  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0      -0.915685  442340.0  -1.374850  ...   -9000.0    -9000.0    -9000.0
# 1       1.659590  159606.0  -3.278290  ...   -9000.0    -9000.0    -9000.0
# 2      -0.085540  365073.0  -4.671140  ...   -9000.0    -9000.0    -9000.0
# 3       2.033900  108049.0  -0.120393  ...   -9000.0    -9000.0    -9000.0
# 4       1.877030  295333.0  -1.575380  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  2.165860  404058.0   1.751460  ...   -9000.0    -9000.0    -9000.0
# 447830 -2.259850  359316.0  -1.069650  ...   -9000.0    -9000.0    -9000.0
# 447831 -2.408950  171236.0   6.623750  ...   -9000.0    -9000.0    -9000.0
# 447832 -2.881930  139393.0   8.095760  ...   -9000.0    -9000.0    -9000.0
# 447833  2.410430   98542.2  -0.506297  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 90 columns]

# %%
ttH_sorted = photons.join(jets3)
ttH_sorted
# Out:
#            y1_pt    y1_eta    y1_phi      y1_E    y2_pt    y2_eta    y2_phi  \
# 0        69864.0 -1.707620 -0.077630  199012.0  52019.0 -2.319050 -2.893570
# 1       112940.0  0.891460 -0.795433  160869.0  78393.9  0.506222 -2.164070
# 2       160426.0 -0.565636 -2.494230  186781.0  41063.0 -0.151729 -0.815176
# 3        73209.9 -0.452546 -2.328690   80835.4  62696.6 -0.374412  1.644870
# 4        61859.6  0.692004  1.046950   77271.5  47359.9  2.224470 -0.873018
# ...          ...       ...       ...       ...      ...       ...       ...
# 447829  461850.0 -1.097410 -1.487300  769012.0  89842.6 -1.163330 -0.872552
# 447830   70181.0  1.600050 -1.234380  180897.0  65702.4  1.024620  2.946560
# 447831  115807.0  0.435172  1.515630  126946.0  60397.4  0.088524 -3.124220
# 447832  110617.0 -1.108200  0.695576  185784.0  93574.4 -1.590040 -0.501275
# 447833   69780.0 -1.119940 -1.191590  118311.0  65355.2  0.542157 -0.801200
#
#             y2_E  Njets   jet1_pt  ...  jet17_pt  jet17_eta  jet17_phi  \
# 0       266972.0    4.0  131378.0  ...   -9000.0    -9000.0    -9000.0
# 1        88654.9    4.0   75861.0  ...   -9000.0    -9000.0    -9000.0
# 2        41536.6    6.0   58465.8  ...   -9000.0    -9000.0    -9000.0
# 3        67142.7    4.0   82384.1  ...   -9000.0    -9000.0    -9000.0
# 4       221566.0    4.0   43564.6  ...   -9000.0    -9000.0    -9000.0
# ...          ...    ...       ...  ...       ...        ...        ...
# 447829  157809.0    7.0   27000.4  ...   -9000.0    -9000.0    -9000.0
# 447830  103316.0    5.0   96707.3  ...   -9000.0    -9000.0    -9000.0
# 447831   60634.2    5.0   37924.0  ...   -9000.0    -9000.0    -9000.0
# 447832  238983.0    4.0   43303.7  ...   -9000.0    -9000.0    -9000.0
# 447833   75197.8    6.0   89664.7  ...   -9000.0    -9000.0    -9000.0
#
#         jet17_E  jet17_DL1R  jet18_pt  jet18_eta  jet18_phi  jet18_E  \
# 0       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 1       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 2       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 3       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 4       -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# ...         ...         ...       ...        ...        ...      ...
# 447829  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447830  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447831  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447832  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
# 447833  -9000.0     -9000.0   -9000.0    -9000.0    -9000.0  -9000.0
#
#         jet18_DL1R
# 0          -9000.0
# 1          -9000.0
# 2          -9000.0
# 3          -9000.0
# 4          -9000.0
# ...            ...
# 447829     -9000.0
# 447830     -9000.0
# 447831     -9000.0
# 447832     -9000.0
# 447833     -9000.0
#
# [447834 rows x 99 columns]

# %%
ttH_sorted.to_csv('ttH_sorted.csv', index = True)

# %%
jets3 = jets3.loc[jets3['jet1_DL1R'] > 0]

# %%
def fomjets(x, num):
    
    string = 'jet' + str(num) + '_'
    E = x[string + 'E']
    px = abs(x[string + 'pt']) * np.cos(x[string + 'phi'])
    py = abs(x[string + 'pt']) * np.sin(x[string + 'phi'])
    pz = x[string + 'pt']/(np.tan(2*np.arctan(np.exp(-x[string + 'eta']))))

    return np.array([E, px, py, pz])

# %%
for i in range (1,4):
    
    jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# Out:
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_16064\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_16064\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)
# C:\Users\s1974479\AppData\Local\Temp\ipykernel_16064\746724520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jets3['jet' + str(i) + '_fom'] = jets3.apply(lambda x: fomjets(x, i), axis = 1).apply(lambda x: x)

# %%
jets3 = jets3.assign(quark_fom = jets3.jet1_fom + jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3 = jets3.assign(wboson_fom = jets3.jet2_fom + jets3.jet3_fom)

# %%
jets3
# Out:
#          jet1_pt  jet1_eta  jet1_phi    jet1_E  jet1_DL1R   jet2_pt  jet2_eta  \
# 0       131378.0 -0.329794  2.391960  139261.0   9.149100  106287.0 -2.103990
# 1        75861.0  0.203770  0.437290   77672.0   9.069050  134531.0 -0.585078
# 2        58465.8 -0.522234  0.606464   67074.4  11.015300  330142.0  0.450489
# 3        82384.1  1.337020 -0.095856  168634.0   9.795330  106924.0  0.095347
# 4        43564.6  1.950350 -2.322560  156360.0   7.904280   48883.5  2.484270
# ...          ...       ...       ...       ...        ...       ...       ...
# 447829   27000.4  0.081570 -1.118100   27644.5   2.824140  251206.0 -1.048900
# 447830   96707.3  1.031870  1.465500  153242.0   6.783540  102291.0  1.928240
# 447831   37924.0  0.613572  0.322380   45686.8   9.146090  149037.0  0.535809
# 447832   43303.7 -2.440290  1.616870  250493.0   8.469340  115269.0 -0.630386
# 447833   89664.7 -1.346250  1.349690  184557.0   0.989877   78635.9 -0.677476
#
#         jet2_phi    jet2_E  jet2_DL1R  ...  jet18_pt  jet18_eta  jet18_phi  \
# 0      -0.915685  442340.0  -1.374850  ...   -9000.0    -9000.0    -9000.0
# 1       1.659590  159606.0  -3.278290  ...   -9000.0    -9000.0    -9000.0
# 2      -0.085540  365073.0  -4.671140  ...   -9000.0    -9000.0    -9000.0
# 3       2.033900  108049.0  -0.120393  ...   -9000.0    -9000.0    -9000.0
# 4       1.877030  295333.0  -1.575380  ...   -9000.0    -9000.0    -9000.0
# ...          ...       ...        ...  ...       ...        ...        ...
# 447829  2.165860  404058.0   1.751460  ...   -9000.0    -9000.0    -9000.0
# 447830 -2.259850  359316.0  -1.069650  ...   -9000.0    -9000.0    -9000.0
# 447831 -2.408950  171236.0   6.623750  ...   -9000.0    -9000.0    -9000.0
# 447832 -2.881930  139393.0   8.095760  ...   -9000.0    -9000.0    -9000.0
# 447833  2.410430   98542.2  -0.506297  ...   -9000.0    -9000.0    -9000.0
#
#         jet18_E  jet18_DL1R  \
# 0       -9000.0     -9000.0
# 1       -9000.0     -9000.0
# 2       -9000.0     -9000.0
# 3       -9000.0     -9000.0
# 4       -9000.0     -9000.0
# ...         ...         ...
# 447829  -9000.0     -9000.0
# 447830  -9000.0     -9000.0
# 447831  -9000.0     -9000.0
# 447832  -9000.0     -9000.0
# 447833  -9000.0     -9000.0
#
#                                                  jet1_fom  \
# 0       [139261.0, -96160.71045778618, 89517.018763215...
# 1       [77672.0, 68722.6798290941, 32126.073493469823...
# 2       [67074.4, 48039.509041460544, 33323.4953253020...
# 3       [168634.0, 82005.89944394439, -7884.9470004357...
# 4       [156360.0, -29751.49208749559, -31823.31050861...
# ...                                                   ...
# 447829  [27644.5, 11809.754898135077, -24280.677284745...
# 447830  [153242.0, 10164.117010485836, 96171.682935712...
# 447831  [45686.8, 35970.309565455704, 12015.2655303695...
# 447832  [250493.0, -1994.4547150293674, 43257.74594312...
# 447833  [184557.0, 19664.28921426147, 87481.8504364641...
#
#                                                  jet2_fom  \
# 0       [442340.0, 64755.091906331756, -84283.47667961...
# 1       [159606.0, -11929.810817710848, 134001.0058725...
# 2       [365073.0, 328934.89668232057, -28205.91974375...
# 3       [108049.0, -47765.839715447895, 95661.72867076...
# 4       [295333.0, -14736.893191366204, 46609.23246864...
# ...                                                   ...
# 447829  [404058.0, -140816.408207909, 208026.905989161...
# 447830  [359316.0, -65037.33859772564, -78953.10803967...
# 447831  [171236.0, -110795.52119783816, -99681.3917012...
# 447832  [139393.0, -111404.79677811869, -29595.8378125...
# 447833  [98542.2, -58536.45076321416, 52507.9870196506...
#
#                                                  jet3_fom  \
# 0       [474586.0, 42469.06493107036, 620.661615157314...
# 1       [109829.0, -84955.81750746298, -23560.93897531...
# 2       [173726.0, -105306.6181624952, 109417.91211761...
# 3       [51423.9, -32049.98679055394, -39283.160109203...
# 4       [97650.7, -20380.51383159554, 26119.3090260853...
# ...                                                   ...
# 447829  [241676.0, 104641.22978318312, 128729.81027898...
# 447830  [268439.0, 46815.95337585933, 51365.2743623487...
# 447831  [40809.8, 39550.4708672386, 1589.542053457782,...
# 447832  [266360.0, -38300.47606950807, 101454.21520000...
# 447833  [80954.6, -72002.00223986596, 29713.2182277574...
#
#                                                 quark_fom  \
# 0       [1056187.0, 11063.44637961594, 5854.2036987614...
# 1       [347107.0, -28162.94849607974, 142566.14039069...
# 2       [605873.4, 271667.7875612859, 114535.487699164...
# 3       [328106.9, 2190.0729379425575, 48493.621561120...
# 4       [549343.7, -64868.899110457336, 40905.23098611...
# ...                                                   ...
# 447829  [673378.5, -24365.423526590792, 312476.0389833...
# 447830  [780997.0, -8057.268211380477, 68583.849258384...
# 447831  [257732.59999999998, -35274.74076514385, -8607...
# 447832  [656246.0, -151699.72756265613, 115116.1233305...
# 447833  [364053.80000000005, -110874.16378881865, 1697...
#
#                                                wboson_fom
# 0       [916926.0, 107224.15683740212, -83662.81506445...
# 1       [269435.0, -96885.62832517384, 110440.06689722...
# 2       [538799.0, 223628.27851982537, 81211.992373862...
# 3       [159472.9, -79815.82650600183, 56378.568561556...
# 4       [392983.7, -35117.40702296174, 72728.541494731...
# ...                                                   ...
# 447829  [645734.0, -36175.17842472588, 336756.71626814...
# 447830  [627755.0, -18221.38522186631, -27587.83367732...
# 447831  [212045.8, -71245.05033059957, -98091.84964779...
# 447832  [405753.0, -149705.27284762677, 71858.37738746...
# 447833  [179496.8, -130538.45300308013, 82221.20524740...
#
# [422789 rows x 95 columns]

# %%
quark_m = []

for row in jets3.quark_fom:
    quark_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(quark_m, bins = 1000, color = 'blue')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('Quark Mass');

# %%
wboson_m = []

for row in jets3.wboson_fom:
    wboson_m.append(np.sqrt( row[0]**2 - row[1]**2 - row[2]**2 - row[3]**2 )/1000)

n, bins, patches = plt.hist(wboson_m, bins = 1000, color = 'green')
plt.xlim(0, 800)
plt.xlabel('Mass GeV')
plt.ylabel('Counts')
plt.title('W boson Mass');
